# %%
import numpy as np
import pandas as pd
import datetime
from matplotlib import pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import nltk
from textblob import TextBlob
import imageio
from nltk.corpus import stopwords
from collections import Counter
from operator import itemgetter

# %%
df= pd.read_csv('netflix_titles_nov_2019.csv.zip')

# %%
df.head(10)
# Out:
#     show_id                                   title  \
# 0  81193313                               Chocolate
# 1  81197050     Guatemala: Heart of the Mayan World
# 2  81213894                         The Zoya Factor
# 3  81082007                               Atlantics
# 4  80213643                         Chip and Potato
# 5  81172754                            Crazy people
# 6  81120982                          I Lost My Body
# 7  81227195  Kalushi: The Story of Solomon Mahlangu
# 8  70205672                        La Reina del Sur
# 9  81172841                    Lagos Real Fake Life
#
#                      director  \
# 0                         NaN
# 1  Luis Ara, Ignacio Jaunsolo
# 2             Abhishek Sharma
# 3                   Mati Diop
# 4                         NaN
# 5                Moses Inwang
# 6               Jérémy Clapin
# 7                 Mandla Dube
# 8                         NaN
# 9              Mike Ezuruonye
#
#                                                 cast  \
# 0  Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                  Christian Morales
# 2  Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3  Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4  Abigail Oliver, Andrea Libman, Briana Buckmast...
# 5  Ramsey Nouah, Chigul, Sola Sobowale, Ireti Doy...
# 6  Hakim Faris, Victoire Du Bois, Patrick d'Assum...
# 7  Thabo Rametsi, Thabo Malema, Welile Nzuza, Jaf...
# 8  Kate del Castillo, Cristina Urgel, Alberto Jim...
# 9  Nonso Diobi, Mike Ezuruonye, Mercy Aigbe, Rex ...
#
#                                   country         date_added  release_year  \
# 0                             South Korea  November 30, 2019          2019
# 1                                     NaN  November 30, 2019          2019
# 2                                   India  November 30, 2019          2019
# 3                France, Senegal, Belgium  November 29, 2019          2019
# 4                  Canada, United Kingdom                NaN          2019
# 5                                 Nigeria  November 29, 2019          2018
# 6                                  France  November 29, 2019          2019
# 7                            South Africa  November 29, 2019          2016
# 8  United States, Spain, Colombia, Mexico                NaN          2019
# 9                                     NaN  November 29, 2019          2018
#
#   rating   duration                                          listed_in  \
# 0  TV-14   1 Season  International TV Shows, Korean TV Shows, Roman...
# 1   TV-G     67 min                Documentaries, International Movies
# 2  TV-14    135 min             Comedies, Dramas, International Movies
# 3  TV-14    106 min   Dramas, Independent Movies, International Movies
# 4   TV-Y  2 Seasons                                           Kids' TV
# 5  TV-14    107 min          Comedies, International Movies, Thrillers
# 6  TV-MA     81 min   Dramas, Independent Movies, International Movies
# 7  TV-MA    107 min                       Dramas, International Movies
# 8  TV-14  2 Seasons  Crime TV Shows, International TV Shows, Spanis...
# 9  TV-14    118 min                     Comedies, International Movies
#
#                                          description     type
# 0  Brought together by meaningful meals in the pa...  TV Show
# 1  From Sierra de las Minas to Esquipulas, explor...    Movie
# 2  A goofy copywriter unwittingly convinces the I...    Movie
# 3  Arranged to marry a rich man, young Ada is cru...    Movie
# 4  Lovable pug Chip starts kindergarten, makes ne...  TV Show
# 5  Nollywood star Ramsey Nouah learns that someon...    Movie
# 6  Romance, mystery and adventure intertwine as a...    Movie
# 7  The life and times of iconic South African lib...    Movie
# 8  This compelling show tells the story of the le...  TV Show
# 9  Two mooching friends vie for the attention of ...    Movie

# %%
## CHECKING FOR DATA TYPES(VALIDATING THE DATA)
df.dtypes
# Out:
# show_id          int64
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# type            object
# dtype: object

# %%
df['show_id']=df['show_id'].astype('object')

# %%
df.dtypes
# Out:
# show_id         object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# type            object
# dtype: object

# %%
### Converting date object to datetime
df['date_added']=pd.to_datetime(df['date_added'])
df['date_added']
# Out:
# 0      2019-11-30
# 1      2019-11-30
# 2      2019-11-30
# 3      2019-11-29
# 4             NaT
#           ...
# 5832   2010-11-01
# 5833   2009-11-18
# 5834   2009-05-05
# 5835   2008-02-04
# 5836   2008-01-01
# Name: date_added, Length: 5837, dtype: datetime64[ns]

# %%
df['year_added']= df['date_added'].dt.year
df
# Out:
#        show_id                                title  \
# 0     81193313                            Chocolate
# 1     81197050  Guatemala: Heart of the Mayan World
# 2     81213894                      The Zoya Factor
# 3     81082007                            Atlantics
# 4     80213643                      Chip and Potato
# ...        ...                                  ...
# 5832  70141644          Mad Ron's Prevues from Hell
# 5833  70127998                             Splatter
# 5834  70084180              Just Another Love Story
# 5835  70157452                      Dinner for Five
# 5836  70053412                 To and From New York
#
#                         director  \
# 0                            NaN
# 1     Luis Ara, Ignacio Jaunsolo
# 2                Abhishek Sharma
# 3                      Mati Diop
# 4                            NaN
# ...                          ...
# 5832                  Jim Monaco
# 5833                   Joe Dante
# 5834                Ole Bornedal
# 5835                         NaN
# 5836        Sorin Dan Mihalcescu
#
#                                                    cast  \
# 0     Ha Ji-won, Yoon Kye-sang, Jang Seung-jo, Kang ...
# 1                                     Christian Morales
# 2     Sonam Kapoor, Dulquer Salmaan, Sanjay Kapoor, ...
# 3     Mama Sane, Amadou Mbow, Ibrahima Traore, Nicol...
# 4     Abigail Oliver, Andrea Libman, Briana Buckmast...
# ...                                                 ...
# 5832  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...
# 5833  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...
# 5834  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...
# 5835                                                NaN
# 5836  Barbara King, Shaana Diya, John Krisiukenas, Y...
#
#                        country date_added  release_year rating   duration  \
# 0                  South Korea 2019-11-30          2019  TV-14   1 Season
# 1                          NaN 2019-11-30          2019   TV-G     67 min
# 2                        India 2019-11-30          2019  TV-14    135 min
# 3     France, Senegal, Belgium 2019-11-29          2019  TV-14    106 min
# 4       Canada, United Kingdom        NaT          2019   TV-Y  2 Seasons
# ...                        ...        ...           ...    ...        ...
# 5832             United States 2010-11-01          1987     NR     84 min
# 5833             United States 2009-11-18          2009  TV-14     29 min
# 5834                   Denmark 2009-05-05          2007     NR    104 min
# 5835             United States 2008-02-04          2007  TV-MA   1 Season
# 5836             United States 2008-01-01          2006     NR     81 min
#
#                                               listed_in  \
# 0     International TV Shows, Korean TV Shows, Roman...
# 1                   Documentaries, International Movies
# 2                Comedies, Dramas, International Movies
# 3      Dramas, Independent Movies, International Movies
# 4                                              Kids' TV
# ...                                                 ...
# 5832                         Cult Movies, Horror Movies
# 5833                                      Horror Movies
# 5834                       Dramas, International Movies
# 5835                       Stand-Up Comedy & Talk Shows
# 5836              Dramas, Independent Movies, Thrillers
#
#                                             description     type  year_added
# 0     Brought together by meaningful meals in the pa...  TV Show      2019.0
# 1     From Sierra de las Minas to Esquipulas, explor...    Movie      2019.0
# 2     A goofy copywriter unwittingly convinces the I...    Movie      2019.0
# 3     Arranged to marry a rich man, young Ada is cru...    Movie      2019.0
# 4     Lovable pug Chip starts kindergarten, makes ne...  TV Show         NaN
# ...                                                 ...      ...         ...
# 5832  This collection cherry-picks trailers, forgott...    Movie      2010.0
# 5833  After committing suicide, a washed-up rocker r...    Movie      2009.0
# 5834  When he causes a car accident that leaves a yo...    Movie      2009.0
# 5835  In each episode, four celebrities join host Jo...  TV Show      2008.0
# 5836  While covering a story in New York City, a Sea...    Movie      2008.0
#
# [5837 rows x 13 columns]

# %%
df.iloc[4]
# Out:
# show_id                                                  80213643
# title                                             Chip and Potato
# director                                                      NaN
# cast            Abigail Oliver, Andrea Libman, Briana Buckmast...
# country                                    Canada, United Kingdom
# date_added                                                    NaT
# release_year                                                 2019
# rating                                                       TV-Y
# duration                                                2 Seasons
# listed_in                                                Kids' TV
# description     Lovable pug Chip starts kindergarten, makes ne...
# type                                                      TV Show
# year_added                                                    NaN
# Name: 4, dtype: object

# %%
#### Checking for any NaN values
df.isnull().any()
# Out:
# show_id         False
# title           False
# director         True
# cast             True
# country          True
# date_added       True
# release_year    False
# rating           True
# duration        False
# listed_in       False
# description     False
# type            False
# year_added       True
# dtype: bool

# %%
# Checking the number of unique values per column
df.nunique()
# Out:
# show_id         5837
# title           5780
# director        3108
# cast            5087
# country          527
# date_added      1092
# release_year      71
# rating            14
# duration         194
# listed_in        449
# description     5829
# type               2
# year_added        12
# dtype: int64

# %%
## Replacing nan values with N/A
df= df.fillna('N/A')

# %%
### Create a dataframe for each year.

df_19= df.loc[df['year_added']==2019]

# %%
df_18=df.loc[df['year_added']==2018]

# %%
df_17=df.loc[df['year_added']==2017]

# %%
### Number of MOvies and TV Shows in 2019
df_19['type'].value_counts()
# Out:
# Movie      1367
# TV Show     476
# Name: type, dtype: int64

# %%
### Countries with the most content
X=df['country'].value_counts()
X=X.to_dict()
X
# Out:
# {'United States': 1907,
#  'India': 697,
#  'N/A': 427,
#  'United Kingdom': 336,
#  'Japan': 168,
#  'Canada': 139,
#  'South Korea': 133,
#  'Spain': 113,
#  'France': 85,
#  'Mexico': 80,
#  'Turkey': 78,
#  'Australia': 69,
#  'Taiwan': 68,
#  'Hong Kong': 51,
#  'Thailand': 50,
#  'Egypt': 49,
#  'China': 48,
#  'Brazil': 48,
#  'Indonesia': 43,
#  'Philippines': 43,
#  'Germany': 40,
#  'United Kingdom, United States': 39,
#  'Argentina': 38,
#  'Canada, United States': 35,
#  'United States, Canada': 34,
#  'United States, United Kingdom': 27,
#  'Nigeria': 26,
#  'Colombia': 25,
#  'France, Belgium': 23,
#  'Italy': 21,
#  'Pakistan': 18,
#  'Malaysia': 17,
#  'Hong Kong, China': 16,
#  'China, Hong Kong': 15,
#  'Singapore': 14,
#  'Russia': 13,
#  'Israel': 13,
#  'Denmark': 12,
#  'United States, Japan': 12,
#  'Chile': 12,
#  'Netherlands': 11,
#  'Poland': 11,
#  'Ireland': 11,
#  'Mexico, United States': 10,
#  'United States, Australia': 9,
#  'United States, France': 9,
#  'United States, Germany': 8,
#  'United States, Mexico': 8,
#  'New Zealand': 8,
#  'Australia, United States': 7,
#  'Norway': 7,
#  'Sweden': 7,
#  'Argentina, Spain': 7,
#  'India, United States': 7,
#  'United States, France, Japan': 6,
#  'United Kingdom, France': 6,
#  'Japan, United States': 6,
#  'Belgium': 5,
#  'United States, India': 5,
#  'Spain, France': 5,
#  'Lebanon': 5,
#  'Germany, United States': 5,
#  'United States, China': 5,
#  'South Korea, United States': 5,
#  'Vietnam': 4,
#  'United States, Czech Republic': 4,
#  'United States, United Kingdom, Australia': 4,
#  'Italy, France': 4,
#  'India, France': 4,
#  'Romania': 4,
#  'United Kingdom, Canada, United States': 4,
#  'South Africa': 4,
#  'France, United States': 4,
#  'United Arab Emirates': 4,
#  'United Kingdom, United States, Spain, Germany, Greece, Canada': 4,
#  'Peru': 4,
#  'United States, Italy': 4,
#  'France, Canada': 3,
#  'India, Turkey': 3,
#  'United States, United Kingdom, France': 3,
#  'Bulgaria, United States': 3,
#  'United States, New Zealand': 3,
#  'United States, Spain': 3,
#  'Canada, United Kingdom, United States': 3,
#  'Australia, United Arab Emirates': 3,
#  'Sweden, United States': 3,
#  'Italy, United States': 3,
#  'Belgium, France': 3,
#  'United Kingdom, Germany': 3,
#  'United States, United Arab Emirates': 3,
#  'Iceland': 3,
#  'United States, Sweden': 3,
#  'Hong Kong, United States': 3,
#  'United Kingdom, Canada': 3,
#  'United Kingdom, France, United States': 2,
#  'United States, Brazil, South Korea, Mexico, Japan, Germany': 2,
#  'Canada, United Kingdom': 2,
#  'Ukraine': 2,
#  'Spain, Argentina': 2,
#  'Israel, United States': 2,
#  'United States, Bulgaria': 2,
#  'United States, Japan, Canada': 2,
#  'United Kingdom, India, United States': 2,
#  'Canada, Australia': 2,
#  'Argentina, Italy': 2,
#  'Czech Republic, United States': 2,
#  'Brazil, France': 2,
#  'United States, South Korea, China': 2,
#  'United Kingdom, India': 2,
#  'Germany, Australia': 2,
#  'United States, South Africa': 2,
#  'Colombia, Mexico, United States': 2,
#  'Indonesia, Singapore': 2,
#  'Austria': 2,
#  'Denmark, United States': 2,
#  'United Kingdom, Ireland': 2,
#  'Switzerland': 2,
#  'United States, United Kingdom, Germany': 2,
#  'United Kingdom, France, Belgium': 2,
#  'India, Soviet Union': 2,
#  'Germany, United Kingdom': 2,
#  'Australia, Canada': 2,
#  'United States, Ireland': 2,
#  'Ireland, United Kingdom, United States': 2,
#  'United Kingdom, Japan, United States': 2,
#  'United States, Chile': 2,
#  'South Africa, United States': 2,
#  'Hungary': 2,
#  'United Arab Emirates, United States': 2,
#  'Canada, United States, United Kingdom': 2,
#  'Singapore, United States': 2,
#  'United States, Germany, Canada': 2,
#  'Germany, United States, Canada': 2,
#  'Switzerland, United States': 2,
#  'Uruguay': 2,
#  'Poland, United States': 2,
#  'Belgium, Netherlands': 2,
#  'France, South Korea, Japan': 2,
#  'Spain, Mexico': 2,
#  'India, Canada': 1,
#  'France, Morocco': 1,
#  'United States, France, Canada, Lebanon, Qatar': 1,
#  'Switzerland, France': 1,
#  'India, Switzerland': 1,
#  'Ireland, United Kingdom': 1,
#  'France, United Kingdom, United States': 1,
#  'South Africa, China, United States': 1,
#  'Norway, Germany': 1,
#  'Canada, India, Thailand, United States, United Arab Emirates': 1,
#  'Germany, Jordan, Netherlands': 1,
#  'Turkey, France, Germany, Poland': 1,
#  'France, United Kingdom': 1,
#  'Georgia, Germany, France': 1,
#  'Canada, Ireland, United States': 1,
#  'United Kingdom, Canada, Japan': 1,
#  'India, Malaysia': 1,
#  'Canada, India': 1,
#  'Australia, India': 1,
#  'United Arab Emirates, Romania': 1,
#  'United States, Brazil': 1,
#  'Spain, Belgium, Switzerland, United States, China, United Kingdom': 1,
#  'Pakistan, United States': 1,
#  'China, India, Nepal': 1,
#  'Venezuela': 1,
#  'United Kingdom, China, Canada, Indonesia, Singapore, United States': 1,
#  'Australia, New Zealand, United States': 1,
#  'France, Canada, Belgium': 1,
#  'Cambodia, United States': 1,
#  'India, Mexico': 1,
#  'Saudi Arabia': 1,
#  'Ireland, Canada, United States, United Kingdom': 1,
#  'Canada, France': 1,
#  'Guatemala': 1,
#  'Ireland, Canada, Luxembourg, United States': 1,
#  'United Kingdom, South Africa, Australia, United States': 1,
#  'Bulgaria, United States, Spain, Canada': 1,
#  'Netherlands, Denmark, France, Germany': 1,
#  'France, Netherlands, South Africa, Finland': 1,
#  'Bulgaria': 1,
#  'Serbia, South Korea, Slovenia': 1,
#  'Somalia, Kenya, Sudan, South Africa, United States': 1,
#  'Norway, Germany, Sweden': 1,
#  'Turkey, India': 1,
#  'United States, Australia, South Africa, United Kingdom': 1,
#  'Norway, Sweden': 1,
#  'Venezuela, Colombia': 1,
#  'Netherlands, Belgium, Germany, Jordan': 1,
#  'Italy, Turkey': 1,
#  'Argentina, Brazil, France, Poland, Germany, Denmark': 1,
#  'Philippines, Qatar': 1,
#  'United Kingdom, Spain, United States, Germany': 1,
#  'United Kingdom, Italy, France, United States': 1,
#  'United States, United Kingdom, Spain, South Korea': 1,
#  'United States, Israel, Italy, South Africa': 1,
#  'Mexico, Spain': 1,
#  'United Kingdom, India, Sweden': 1,
#  'Spain, Colombia': 1,
#  'South Korea, China, United States': 1,
#  'United States, Nicaragua': 1,
#  'Australia, New Zealand': 1,
#  'Canada, Germany, South Africa': 1,
#  'Thailand, United States': 1,
#  'Italy, Canada, France': 1,
#  'Denmark, Germany, Belgium, United Kingdom, France': 1,
#  'Canada, France, Italy, Morocco, United States': 1,
#  'Germany, Belgium': 1,
#  'United States, India, Bangladesh': 1,
#  'Czech Republic, United Kingdom, France': 1,
#  'Brazil, India, China, United States': 1,
#  'United Kingdom, United States, Dominican Republic': 1,
#  'Soviet Union, India': 1,
#  'South Africa, Germany, Netherlands, France': 1,
#  'United States, Canada, Belgium, United Kingdom': 1,
#  'Portugal, France, Poland, United States': 1,
#  'New Zealand, United Kingdom': 1,
#  'Georgia': 1,
#  'United Kingdom, Namibia, South Africa, Zimbabwe, United States': 1,
#  'United States, Denmark': 1,
#  'Brazil, Netherlands, United States, Colombia, Austria, Germany': 1,
#  'United States, United Kingdom, Denmark, Sweden': 1,
#  'Spain, Cuba': 1,
#  'Chile, United States, France': 1,
#  'United States, Russia': 1,
#  'Ireland, South Africa': 1,
#  'Netherlands, Denmark, South Africa': 1,
#  'United Kingdom, Germany, Canada': 1,
#  'United Kingdom, Australia, Canada, United States': 1,
#  'France, Qatar': 1,
#  'Peru, United States, United Kingdom': 1,
#  'United States, Kazakhstan': 1,
#  'France, Germany': 1,
#  'United States, Hungary': 1,
#  'Canada, Japan, Netherlands': 1,
#  'United Kingdom, Spain, Belgium': 1,
#  'Brazil, Canada': 1,
#  'Israel, Germany, France': 1,
#  'Turkey, Azerbaijan': 1,
#  'United States, Venezuela': 1,
#  'Belgium, Ireland, Netherlands, Germany, Afghanistan': 1,
#  'Netherlands, Germany, Italy, Canada': 1,
#  'Norway, Denmark, Sweden': 1,
#  'United Kingdom, Jordan, Qatar, Iran': 1,
#  'Lebanon, Qatar': 1,
#  'United States, Greece, Brazil': 1,
#  'Austria, Czech Republic': 1,
#  'United States, Greece, United Kingdom': 1,
#  'Pakistan, Norway, United States': 1,
#  'France, Belgium, Spain': 1,
#  'Argentina, Chile, Peru': 1,
#  'United Kingdom, Egypt, United States': 1,
#  'United States, Hungary, Ireland, Canada': 1,
#  'United States, Bermuda, Ecuador': 1,
#  'United Kingdom,': 1,
#  'Norway, United States': 1,
#  'Australia, United Kingdom, United States, New Zealand, Italy, France': 1,
#  'United Kingdom, United States, Greece, Italy, Germany': 1,
#  'Norway, United Kingdom, France, Ireland': 1,
#  'United Kingdom, Ukraine, United States': 1,
#  'Australia, France, Ireland': 1,
#  'France, United States, Canada': 1,
#  'United States, Netherlands, Japan, France': 1,
#  'United States, New Zealand, Japan': 1,
#  'Canada, United Kingdom, Netherlands': 1,
#  'Denmark, Indonesia, Finland, Norway, United Kingdom, Israel, France, United States, Germany, Netherlands': 1,
#  'China, United States': 1,
#  'United Arab Emirates, Jordan': 1,
#  'China, Germany, India, United States': 1,
#  'Denmark, Zimbabwe': 1,
#  'Mexico, France': 1,
#  'Croatia, Slovenia, Serbia, Montenegro': 1,
#  'India, United Kingdom': 1,
#  'Denmark, United Kingdom': 1,
#  'Ireland, United Kingdom, Italy, United States': 1,
#  'China, South Korea, United States': 1,
#  'Netherlands, Belgium, United Kingdom, United States': 1,
#  'France, China, Canada': 1,
#  'Israel, Sweden, Germany, Netherlands': 1,
#  'United States, Canada, Japan, Panama': 1,
#  'United States, Iceland': 1,
#  'Netherlands, United States': 1,
#  'Chile, Argentina, France, Spain, United States': 1,
#  'Russia, United States': 1,
#  'Slovenia, Croatia, Germany, Czech Republic, Qatar': 1,
#  'Chile, France': 1,
#  'Germany, United States, Hong Kong, Singapore': 1,
#  'Spain, Germany': 1,
#  'United Kingdom, France, Belgium, United States': 1,
#  'United States, Argentina': 1,
#  'Belgium, India, Australia': 1,
#  'Australia, Armenia, Japan, Jordan, Mexico, Mongolia, New Zealand, Philippines, South Africa, Sweden, United States, Uruguay': 1,
#  'Italy, Germany': 1,
#  'Canada, Spain': 1,
#  'Germany, United States, Italy': 1,
#  'Argentina, Uruguay, Spain, France': 1,
#  'United Kingdom, Italy, Israel, Peru, United States': 1,
#  'United States, Hong Kong': 1,
#  'United States, Colombia, Mexico': 1,
#  'United States, Senegal': 1,
#  'Czech Republic, France': 1,
#  'United States, Uruguay': 1,
#  'United Kingdom, France, Canada, Belgium, United States': 1,
#  'Finland, Sweden, Norway, Latvia, Germany': 1,
#  'France, United Kingdom, India': 1,
#  'United Kingdom, Israel, Russia': 1,
#  'Italy, India': 1,
#  'West Germany': 1,
#  'France, Germany, Switzerland': 1,
#  'Chile, Spain, Argentina, Germany': 1,
#  'Spain, Italy, Argentina': 1,
#  'Germany, Sri Lanka': 1,
#  'Denmark, United Kingdom, South Africa, Sweden, Belgium': 1,
#  'Portugal, Spain': 1,
#  'India, Germany': 1,
#  'United States, Botswana': 1,
#  'Japan, Canada': 1,
#  'United Kingdom, Russia': 1,
#  'Netherlands, Belgium': 1,
#  'United Kingdom, Singapore': 1,
#  'South Africa, United States, Germany': 1,
#  'United States, Australia, China': 1,
#  'Spain, Switzerland': 1,
#  'United States, Australia, Samoa, United Kingdom': 1,
#  'Singapore, France': 1,
#  'Colombia, United States': 1,
#  'Spain, France, Uruguay': 1,
#  'Czech Republic, Slovakia': 1,
#  'United Kingdom, South Africa': 1,
#  'Saudi Arabia, Syria, Egypt, Lebanon, Kuwait': 1,
#  'United Kingdom, Canada, United States, Cayman Islands': 1,
#  'South Korea, France': 1,
#  'United Kingdom, Norway, Denmark, Germany, Sweden': 1,
#  'Canada, Brazil': 1,
#  'United Kingdom, Belgium, Sweden': 1,
#  'United States, Mexico, Spain, Malta': 1,
#  'United States, Canada, United Kingdom': 1,
#  'India, Germany, France': 1,
#  'Chile, Argentina': 1,
#  'United Kingdom, Pakistan': 1,
#  'Denmark, Spain': 1,
#  'United Kingdom, Thailand': 1,
#  'United States, France, United Kingdom, Japan': 1,
#  'France, China, Japan, United States': 1,
#  'Spain, France, Italy': 1,
#  'France, Luxembourg, Canada': 1,
#  'Uruguay, Spain, Mexico': 1,
#  'Lebanon, Jordan': 1,
#  'Germany, United States, Sweden': 1,
#  'Argentina, United States': 1,
#  'Thailand, China, United States': 1,
#  'Dominican Republic': 1,
#  'United States, Czech Republic, United Kingdom': 1,
#  'Germany, United Kingdom, United States': 1,
#  'South Korea, Czech Republic': 1,
#  'France, Netherlands, Singapore': 1,
#  'Italy, France, Switzerland': 1,
#  'Cyprus, Austria, Thailand': 1,
#  'Paraguay, Argentina': 1,
#  'United Kingdom, Malawi': 1,
#  'Taiwan, Hong Kong, United States, China': 1,
#  'Austria, Iraq, United States': 1,
#  'United States, Cambodia': 1,
#  'Austria, United States': 1,
#  'India, Japan': 1,
#  'United Kingdom, Canada, France, United States': 1,
#  'United Kingdom, United States, Czech Republic': 1,
#  'United States, Taiwan': 1,
#  'United Arab Emirates, United Kingdom, India': 1,
#  'Finland': 1,
#  'Iran, France': 1,
#  'Canada, United States, India, United Kingdom': 1,
#  'Mexico, Finland': 1,
#  'Ghana, United States': 1,
#  'United States, Germany, United Kingdom': 1,
#  'Pakistan, United Arab Emirates': 1,
#  'Ireland, United States, France': 1,
#  'Hong Kong, China, Singapore': 1,
#  'United States, Morocco': 1,
#  'China, Hong Kong, United States': 1,
#  'Germany, Italy': 1,
#  'United Kingdom, United States, Russia': 1,
#  'Egypt, Austria, United States': 1,
#  'Canada, Luxembourg': 1,
#  'Singapore, Malaysia': 1,
#  'Italy, Belgium, France': 1,
#  'United States, France, Canada, Spain': 1,
#  'United States, United Kingdom, Italy': 1,
#  'United States, Italy, United Kingdom, Liechtenstein': 1,
#  'United States, South Korea, Japan': 1,
#  'United States, Australia, Mexico': 1,
#  'South Africa, United States, New Zealand, Canada': 1,
#  'United States, United Kingdom, Canada': 1,
#  'Argentina, United States, Mexico': 1,
#  'United States, Spain, Chile, Peru': 1,
#  'Finland, Germany, Belgium': 1,
#  'United Kingdom, Germany, United States': 1,
#  'United States, New Zealand, United Kingdom': 1,
#  'Australia, France': 1,
#  'United Kingdom, Germany, Canada, United States': 1,
#  'Canada, Norway': 1,
#  'Germany, Canada, United States': 1,
#  'United States, Spain, Colombia, Mexico': 1,
#  'France, Senegal, Belgium': 1,
#  'United States, Spain, Germany': 1,
#  'Belgium, Luxembourg, France': 1,
#  'Taiwan, China, France, United States': 1,
#  'United Kingdom, Poland, United States': 1,
#  'Philippines, Singapore': 1,
#  'United Kingdom, Poland': 1,
#  'Singapore, Japan, France': 1,
#  'United States, Germany, Australia': 1,
#  'United Kingdom, South Korea': 1,
#  'Malaysia, Singapore, Hong Kong': 1,
#  'Israel, Germany, Poland, Luxembourg, Belgium, France, United States': 1,
#  'China, Taiwan': 1,
#  'China, United Kingdom': 1,
#  'Denmark, Brazil, France, Portugal, Sweden': 1,
#  'Brazil, United States': 1,
#  'United States, India, South Korea, China': 1,
#  'Japan, Canada, South Korea': 1,
#  'France, Switzerland, Spain, United States, United Arab Emirates': 1,
#  'United Kingdom, France, Germany, Spain': 1,
#  'Denmark, France, Italy, Belgium, Netherlands': 1,
#  'United States, Malta, United Kingdom': 1,
#  'Poland, West Germany': 1,
#  'Poland,': 1,
#  'Denmark, France, Poland': 1,
#  'United Kingdom, Hong Kong': 1,
#  'United States, Spain, Italy': 1,
#  'United Kingdom, France, Germany': 1,
#  'Italy, United States, Argentina': 1,
#  'United Kingdom, New Zealand': 1,
#  'United States, China, Hong Kong': 1,
#  'Argentina, France': 1,
#  'China, Japan': 1,
#  'India, Iran': 1,
#  'Finland, Germany': 1,
#  'Denmark, Germany, Belgium, United Kingdom, France, Sweden': 1,
#  'India, Germany, Austria': 1,
#  'Belgium, United Kingdom, United States': 1,
#  'China, Canada, United States': 1,
#  'United States,': 1,
#  'United States, France, South Korea, Indonesia': 1,
#  'United States, United Kingdom, Canada, Japan': 1,
#  'Turkey, United States': 1,
#  'India, Australia': 1,
#  'United Kingdom, West Germany': 1,
#  'United Kingdom, Canada, Italy': 1,
#  'Norway, Iceland, United States': 1,
#  'Egypt, France': 1,
#  'United States, Israel, United Kingdom, Canada': 1,
#  'United States, Ireland, United Kingdom': 1,
#  'Indonesia, United States': 1,
#  'Canada, Mexico, Germany, South Africa': 1,
#  'United States, Brazil, India, Uganda, China': 1,
#  'Mexico, Argentina': 1,
#  'China, United States, United Kingdom': 1,
#  'Cambodia': 1,
#  'Canada, United States, France': 1,
#  'Italy, Switzerland, Albania, Poland': 1,
#  'Canada, Japan, United States': 1,
#  'Denmark, France, United States, Sweden': 1,
#  'Denmark, Sweden, Israel, United States': 1,
#  'United Kingdom, United States, Australia': 1,
#  'Chile, Peru': 1,
#  'United States, Canada, Ireland': 1,
#  'Russia, Spain': 1,
#  'Colombia, Mexico': 1,
#  'Hong Kong, Taiwan': 1,
#  'China, United States, Australia': 1,
#  'France, Luxembourg, United States': 1,
#  'Germany, France, Luxembourg, United Kingdom, United States': 1,
#  'Switzerland, United Kingdom, United States': 1,
#  'Argentina, France, Germany': 1,
#  'United Kingdom, Denmark, Canada, Croatia': 1,
#  'Canada, Spain, France': 1,
#  'Australia, United Kingdom, Canada': 1,
#  'Ireland, Canada, United Kingdom, United States': 1,
#  'United States, United Kingdom, Morocco': 1,
#  'United Kingdom, United States, Morocco': 1,
#  'Finland, France': 1,
#  'Australia, United Kingdom, United Arab Emirates, Canada': 1,
#  'Sweden, Netherlands': 1,
#  'Uruguay, Argentina, Spain': 1,
#  'United Kingdom, Brazil, Germany': 1,
#  'Croatia': 1,
#  'France, United States, Mexico': 1,
#  'Switzerland, Vatican City, Italy, Germany, France': 1,
#  'Iceland, Sweden, Belgium': 1,
#  'India, Nepal': 1,
#  'Bangladesh': 1,
#  'Italy, South Africa, West Germany, Australia, United States': 1,
#  'Spain, United Kingdom': 1,
#  'United States, Colombia': 1,
#  'Spain, United Kingdom, United States': 1,
#  'Italy, United Kingdom, France': 1,
#  'Spain, Belgium': 1,
#  'India, Pakistan': 1,
#  'United States, India, United Arab Emirates': 1,
#  'France, Germany, Czech Republic, Belgium': 1,
#  'Denmark, China': 1,
#  'Denmark, Singapore, Canada, United States': 1,
#  'United Kingdom, United States, France, Germany': 1,
#  'France, Poland': 1,
#  'United States, Mexico, Colombia': 1,
#  'Spain, Portugal': 1,
#  'Thailand, Canada, United States': 1,
#  'Serbia, United States': 1,
#  'Russia, Poland, Serbia': 1,
#  'United States, Indonesia': 1,
#  'France, Belgium, China, United States': 1,
#  'United Kingdom, China, United States': 1,
#  'New Zealand, United Kingdom, Australia': 1,
#  'France, Iran, United States': 1,
#  'Argentina, Chile': 1,
#  'Germany, France, Russia': 1,
#  'Australia, Iraq': 1,
#  'United Arab Emirates, United States, United Kingdom': 1,
#  'China, Morocco, Hong Kong': 1,
#  'Mexico, Netherlands': 1,
#  'Italy, Switzerland, France, Germany': 1,
#  'United States, France, Canada': 1,
#  'Ireland, Canada': 1,
#  'Hong Kong, China, United States': 1,
#  'Norway, Denmark, Netherlands, Sweden': 1,
#  'Ireland, United Kingdom, Greece, France, Netherlands': 1,
#  'Israel, Germany': 1,
#  'Canada, Germany, France, United States': 1,
#  'Spain, Mexico, France': 1}

# %%
 ### Countries with the most content

plt.figure(figsize=(8,8))
sns.set_theme(style='darkgrid')
ax=sns.barplot(x= list(X.keys())[:10],y= list(X.values())[:10],palette="dark")
ax.set_xticklabels(list(X.keys())[:10],rotation=45)
# Out:
# [Text(0, 0, 'United States'),
#  Text(1, 0, 'India'),
#  Text(2, 0, 'N/A'),
#  Text(3, 0, 'United Kingdom'),
#  Text(4, 0, 'Japan'),
#  Text(5, 0, 'Canada'),
#  Text(6, 0, 'South Korea'),
#  Text(7, 0, 'Spain'),
#  Text(8, 0, 'France'),
#  Text(9, 0, 'Mexico')]

# %%
### Pie- chart showing the the number of movies and series added in 2019
plt.figure(figsize=(16,6))

plt.subplot(131)
plt.pie(df_19['type'].value_counts(),labels=['Movies','Series'],autopct='%.0f%%')
plt.title('2019')

plt.subplot(132)
plt.pie(df_18['type'].value_counts(),labels=['Movies','Series'],autopct='%.0f%%')
plt.title('2018')

plt.subplot(133)
plt.pie(df_17['type'].value_counts(),labels=['Movies','Series'],autopct='%.0f%%')
plt.title('2017')

plt.suptitle('Content aired in recent years')


plt.show()

# %%
### CReating data frames for each year with Movie type 
df_m19= df_19.loc[df_19['type']=='Movie']

# %%
df_m18= df_18.loc[df_18['type']=='Movie']

# %%
df_m17= df_17.loc[df_17['type']=='Movie']

# %%
## Showing the rating of the various movies added in 2019
plt.figure(figsize=[18,12])


plt.subplot(151)
sns.set_theme(style='whitegrid')
ax=sns.countplot(x=df_m19['rating'],data=df_m19,palette="colorblind")
ax.set_xticklabels(df_m19['rating'].unique(),rotation=90)
plt.title('2019')

plt.subplot(153)
sns.set_theme(style='whitegrid')
ax=sns.countplot(x=df_m18['rating'],data=df_m18,palette="colorblind")
ax.set_xticklabels(df_m18['rating'].unique(),rotation=90)
plt.title('2018')

plt.subplot(155)
sns.set_theme(style='darkgrid')
ax=sns.countplot(x=df_m17['rating'],data=df_m17,palette="colorblind")
ax.set_xticklabels(df_m17['rating'].unique(),rotation=90)
plt.title('2017')

plt.suptitle('Rated movies added in recent years')
# Out:
# Text(0.5, 0.98, 'Rated movies added in recent years')

# %%
## Movies shown in each year
df_m= df.loc[df['type']=='Movie']

# %%
### Years with the most movies releaseding

plt.figure(figsize=(12,10))
sns.set_theme(style='whitegrid')
ax=sns.countplot(x=df_m['release_year'],data=df_m,palette='muted',order=df_m['release_year'].value_counts().index[:20])

plt.title('Number of Movies added over the years')
# Out:
# Text(0.5, 1.0, 'Number of Movies added over the years')

# %%
## The duration for TV Shows
df_s=df.loc[df['type']=='TV Show']
df_s['duration'].value_counts()
# Out:
# 1 Season      1259
# 2 Seasons      298
# 3 Seasons      157
# 4 Seasons       60
# 5 Seasons       46
# 6 Seasons       21
# 7 Seasons       21
# 8 Seasons       16
# 9 Seasons        7
# 11 Seasons       3
# 10 Seasons       3
# 15 Seasons       2
# 13 Seasons       2
# 12 Seasons       2
# 14 Seasons       1
# Name: duration, dtype: int64

# %%
### Years with the most Tv Shows released
plt.figure(figsize=(12,10))
sns.set_theme(style='whitegrid')
ax=sns.countplot(x=df_s['release_year'],data=df_s,palette='muted',order=df_s['release_year'].value_counts().index[:10])
ax.set_xticklabels(df_s['release_year'].unique()[:10],rotation=45)
plt.title('TV Shows released over the years')
# Out:
# Text(0.5, 1.0, 'TV Shows released over the years')

# %%
sns.set_theme(style='darkgrid')
ax=sns.countplot(x=df_s['duration'],data=df_s,palette="dark")
ax.set_xticklabels(df_s['duration'].unique(),rotation=45)
plt.title('The overall number of seasons shows aired')
### We can see that most shows on Netflix do not run for long maybeby popularity
# Out:
# Text(0.5, 1.0, 'The overall number of seasons shows aired')

# %%
df_s=df.loc[df['duration']=='15 Seasons']
df_s
## Grey's Anatomy and NCIS are the Longest Running Shows
# Out:
#        show_id           title director  \
# 1109  70140391  Grey's Anatomy      N/A
# 3160  70142386            NCIS      N/A
#
#                                                    cast        country  \
# 1109  Ellen Pompeo, Sandra Oh, Katherine Heigl, Just...  United States
# 3160  Mark Harmon, Michael Weatherly, Pauley Perrett...  United States
#
#      date_added  release_year rating    duration  \
# 1109        N/A          2018  TV-14  15 Seasons
# 3160        N/A          2017  TV-14  15 Seasons
#
#                                     listed_in  \
# 1109             Romantic TV Shows, TV Dramas
# 3160  Crime TV Shows, TV Dramas, TV Mysteries
#
#                                             description     type year_added
# 1109  Intern (and eventual resident) Meredith Grey f...  TV Show        N/A
# 3160  Follow the quirky agents of the NCIS – the Nav...  TV Show        N/A

# %%
## Popular Genres of 2019
genres_19=list(df_19['listed_in'])
genres_19=' '.join(genres_19)

# %%
## Creating  A word cloud for genres for 2019
text = genres_19
mask_image = imageio.imread('Netflix Image_3.png')
plt.figure(figsize=[9,9])
wordcloud = WordCloud(colormap='plasma',mask=mask_image,background_color='white')
wordcloud = wordcloud.generate(text)
wordcloud = wordcloud.to_file('Netflix Image 2.png')
plt.imshow(wordcloud)

# %%
### genres for 2018
genres_18=list(df_18['listed_in'])
genres_18=' '.join(genres_18)

# %%
#### Word cloud for genres 2018
text = genres_18
mask_image = imageio.imread('Netflix Image_3.png')
plt.figure(figsize=[6,6])
wordcloud = WordCloud(colormap='plasma',mask=mask_image,background_color='white')
wordcloud = wordcloud.generate(text)
wordcloud = wordcloud.to_file('Netflix Image 3.png')
plt.imshow(wordcloud)

# %%
### Converting the description column to plain text
summary=list(df_19['description'])
summary=' '.join(summary)
summary
# Out:
# 'Brought together by meaningful meals in the past and present, a doctor and a chef are reacquainted when they begin working at a hospice ward. From Sierra de las Minas to Esquipulas, explore Guatemala\'s cultural and geological wealth, including ancient Mayan cities and other natural wonders. A goofy copywriter unwittingly convinces the Indian cricket team that she’s their lucky mascot, to the dismay of their superstition-shunning captain. Arranged to marry a rich man, young Ada is crushed when her true love goes missing at sea during a migration attempt – until a miracle reunites them. Nollywood star Ramsey Nouah learns that someone is impersonating him and breaks out of a mental institution to expose the imposter. Romance, mystery and adventure intertwine as a young man falls in love and a severed hand scours Paris for its owner in this mesmerizing animated film. The life and times of iconic South African liberation fighter Solomon Mahlangu, who battled the forces of apartheid, come into focus. Two mooching friends vie for the attention of wealthy, beautiful women only to discover that their lavish lifestyles are bogus. After an expensive night out, two flatmates get tangled in an overnight misadventure to recover their rent money to pay their dead landlord\'s daughter. It\'s everything you love about "Sugar Rush" – with a holly jolly holiday twist – in this Christmas-themed spin on competitive baking. Nursing a broken heart, an IT specialist moves to London to audition for a reality TV show that unexpectedly turns into a real-life cartel drama. A quirky fashion student becomes the nanny of a handsome widower’s three kids, experiencing a series of silly antics and schemes. When a colonel uncovers controversial intel about the government, he makes a shocking discovery and must decide whether to reveal it or risk his life. These blockbusters brought us together and gave us the time of our lives. Meet the actors, directors and industry insiders who made them happen. A widowed radio DJ and his four spoiled kids need to tighten their belts and pull together when their life of luxury turns lean just before Christmas. Young Levius rises through the ranks in the brutal world of metal boxing under his uncle\'s guidance. Forces outside the ring have their eye on him. Four comedians from Brazil riff on sexuality, politics, religion and motherhood – and set out to prove a woman\'s place is anywhere she wants it to be. A struggling LA musician tries to win over his new girlfriend\'s gruff dad and quirky, tight-knit siblings on a 10-day Christmas visit to Philadelphia. Burned out and taken for granted, a working mom suspects her partner is cheating, so to win back his attentions, she feigns a medical diagnosis. Ready-to-retire safecracker Nick, flamboyant fence Max and talented but volatile thief Jackie team up to rob the Montreal Customs House. This investigative docuseries shows how negligence and deceit in the production and marketing of popular consumer items can result in dire outcomes. In this action-packed drama based on an extraordinary true story, four brothers protect more than 1,000 Jewish refugees during World War II. When caste differences throw a wrench into their otherwise blossoming relationship, a couple must somehow convince the girl’s father to let them marry. In a journey back in time to the ancient city of Mirchigadh, Little Singham vies for the title of Ultimate Warrior and fights a zombie king’s army. After a traumatic event, two Indigenous women in Vancouver are brought together and form a deep bond despite leading different lives. Hit man Frank Sheeran looks back at the secrets he kept as a loyal member of the Bufalino crime family in this acclaimed film from Martin Scorsese. Comedian Mike Birbiglia hits Broadway with a hilarious yet profound one-man show that recounts his emotional and physical journey to parenthood. It\'s Christmas Eve in Pitchfork Pines, and the Super Monsters are joining forces to deck the hal ...

# %%
blob= TextBlob(summary)
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Vicky\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stop_words=stopwords.words('english')

# %%
add=['–',',','’','/',]
stop_words.extend(add)
items=blob.word_counts.items()
items=[item for item in items if item[0] not in stop_words ]
items
# Out:
# [('brought', 6),
#  ('together', 32),
#  ('meaningful', 1),
#  ('meals', 1),
#  ('past', 41),
#  ('present', 4),
#  ('doctor', 13),
#  ('chef', 17),
#  ('reacquainted', 1),
#  ('begin', 12),
#  ('working', 7),
#  ('hospice', 1),
#  ('ward', 2),
#  ('sierra', 1),
#  ('de', 7),
#  ('las', 8),
#  ('minas', 1),
#  ('esquipulas', 1),
#  ('explore', 14),
#  ('guatemala', 1),
#  ('cultural', 10),
#  ('geological', 1),
#  ('wealth', 4),
#  ('including', 7),
#  ('ancient', 12),
#  ('mayan', 1),
#  ('cities', 2),
#  ('natural', 4),
#  ('wonders', 2),
#  ('goofy', 2),
#  ('copywriter', 2),
#  ('unwittingly', 4),
#  ('convinces', 3),
#  ('indian', 8),
#  ('cricket', 4),
#  ('team', 34),
#  ('lucky', 2),
#  ('mascot', 1),
#  ('dismay', 1),
#  ('superstition-shunning', 1),
#  ('captain', 5),
#  ('arranged', 3),
#  ('marry', 16),
#  ('rich', 11),
#  ('man', 126),
#  ('young', 139),
#  ('ada', 1),
#  ('crushed', 1),
#  ('true', 48),
#  ('love', 99),
#  ('goes', 35),
#  ('missing', 19),
#  ('sea', 3),
#  ('migration', 1),
#  ('attempt', 11),
#  ('miracle', 2),
#  ('reunites', 6),
#  ('nollywood', 1),
#  ('star', 23),
#  ('ramsey', 1),
#  ('nouah', 1),
#  ('learns', 19),
#  ('someone', 6),
#  ('impersonating', 1),
#  ('breaks', 11),
#  ('mental', 6),
#  ('institution', 4),
#  ('expose', 5),
#  ('imposter', 1),
#  ('romance', 34),
#  ('mystery', 10),
#  ('adventure', 19),
#  ('intertwine', 1),
#  ('falls', 34),
#  ('severed', 1),
#  ('hand', 1),
#  ('scours', 1),
#  ('paris', 12),
#  ('owner', 9),
#  ('mesmerizing', 1),
#  ('animated', 13),
#  ('film', 23),
#  ('life', 176),
#  ('times', 4),
#  ('iconic', 7),
#  ('south', 13),
#  ('african', 3),
#  ('liberation', 1),
#  ('fighter', 7),
#  ('solomon', 2),
#  ('mahlangu', 1),
#  ('battled', 1),
#  ('forces', 27),
#  ('apartheid', 2),
#  ('come', 31),
#  ('focus', 3),
#  ('two', 106),
#  ('mooching', 1),
#  ('friends', 83),
#  ('vie', 4),
#  ('attention', 7),
#  ('wealthy', 21),
#  ('beautiful', 14),
#  ('women', 41),
#  ('discover', 22),
#  ('lavish', 3),
#  ('lifestyles', 2),
#  ('bogus', 1),
#  ('expensive', 1),
#  ('night', 17),
#  ('flatmates', 2),
#  ('get', 42),
#  ('tangled', 4),
#  ('overnight', 2),
#  ('misadventure', 1),
#  ('recover', 5),
#  ('rent', 1),
#  ('money', 15),
#  ('pay', 3),
#  ('dead', 14),
#  ('landlord', 2),
#  ('daughter', 49),
#  ('everything', 16),
#  ('sugar', 4),
#  ('rush', 2),
#  ('holly', 2),
#  ('jolly', 1),
#  ('holiday', 9),
#  ('twist', 2),
#  ('christmas-themed', 1),
#  ('spin', 2),
#  ('competitive', 3),
#  ('baking', 1),
#  ('nursing', 2),
#  ('broken', 4),
#  ('heart', 19),
#  ('specialist', 1),
#  ('moves', 19),
#  ('london', 13),
#  ('audition', 2),
#  ('reality', 23),
#  ('tv', 14),
#  ('show', 34),
#  ('unexpectedly', 4),
#  ('turns', 31),
#  ('real-life', 8),
#  ('cartel', 3),
#  ('drama', 25),
#  ('quirky', 4),
#  ('fashion', 9),
#  ('student', 45),
#  ('becomes', 39),
#  ('nanny', 3),
#  ('handsome', 9),
#  ('widower', 1),
#  ('three', 56),
#  ('kids', 19),
#  ('experiencing', 2),
#  ('series', 69),
#  ('silly', 4),
#  ('antics', 2),
#  ('schemes', 5),
#  ('colonel', 1),
#  ('uncovers', 9),
#  ('controversial', 5),
#  ('intel', 1),
#  ('government', 14),
#  ('makes', 13),
#  ('shocking', 7),
#  ('discovery', 4),
#  ('must', 81),
#  ('decide', 15),
#  ('whether', 6),
#  ('reveal', 9),
#  ('risk', 6),
#  ('blockbusters', 1),
#  ('us', 6),
#  ('gave', 1),
#  ('time', 47),
#  ('lives', 61),
#  ('meet', 23),
#  ('actors', 3),
#  ('directors', 3),
#  ('industry', 8),
#  ('insiders', 2),
#  ('made', 8),
#  ('happen', 4),
#  ('widowed', 9),
#  ('radio', 4),
#  ('dj', 5),
#  ('four', 48),
#  ('spoiled', 5),
#  ('need', 10),
#  ('tighten', 1),
#  ('belts', 1),
#  ('pull', 4),
#  ('luxury', 3),
#  ('lean', 1),
#  ('christmas', 10),
#  ('levius', 1),
#  ('rises', 5),
#  ('ranks', 2),
#  ('brutal', 11),
#  ('world', 102),
#  ('metal', 1),
#  ('boxing', 4),
#  ('uncle', 7),
#  ('guidance', 2),
#  ('outside', 8),
#  ('ring', 12),
#  ('eye', 7),
#  ('comedians', 3),
#  ('brazil', 4),
#  ('riff', 1),
#  ('sexuality', 4),
#  ('politics', 8),
#  ('religion', 5),
#  ('motherhood', 1),
#  ('set', 20),
#  ('prove', 11),
#  ('woman', 100),
#  ('place', 8),
#  ('anywhere', 2),
#  ('wants', 9),
#  ('struggling', 17),
#  ('la', 10),
#  ('musician', 9),
#  ('tries', 42),
#  ('win', 18),
#  ('new', 127),
#  ('girlfriend', 21),
#  ('gruff', 2),
#  ('dad', 9),
#  ('tight-knit', 2),
#  ('siblings', 12),
#  ('10-day', 1),
#  ('visit', 5),
#  ('philadelphia', 4),
#  ('burned', 2),
#  ('taken', 11),
#  ('granted', 2),
#  ('mom', 16),
#  ('suspects', 8),
#  ('partner', 11),
#  ('cheating', 4),
#  ('back', 52),
#  ('attentions', 1),
#  ('feigns', 1),
#  ('medical', 11),
#  ('diagnosis', 3),
#  ('ready-to-retire', 1),
#  ('safecracker', 1),
#  ('nick', 2),
#  ('flamboyant', 1),
#  ('fence', 2),
#  ('max', 2),
#  ('talented', 6),
#  ('volatile', 2),
#  ('thief', 5),
#  ('jackie', 2),
#  ('rob', 4),
#  ('montreal', 1),
#  ('customs', 2),
#  ('house', 19),
#  ('investigative', 2),
#  ('docuseries', 5),
#  ('shows', 9),
#  ('negligence', 1),
#  ('deceit', 5),
#  ('production', 6),
#  ('marketing', 4),
#  ('popular', 12),
#  ('consumer', 1),
#  ('items', 2),
#  ('result', 1),
#  ('dire', 4),
#  ('outcomes', 1),
#  ('action-packed', 4),
#  ('based', 31),
#  ('extraordinary', 9),
#  ('story', 28),
#  ('brothers', 18),
#  ('protect', 13),
#  ('1,000', 1),
#  ('jewish', 8),
#  ('refugees', 5),
#  ('war', 43),
#  ('ii', 13),
#  ('caste', 6),
#  ('differences', 5),
#  ('throw', 3),
#  ('wrench', 1),
#  ('otherwise', 2),
#  ('blossoming', 2),
#  ('relationship', 27),
#  ('couple', 33),
#  ('somehow', 1),
#  ('convince', 2),
#  ('girl', 49),
#  ('father', 67),
#  ('let', 1),
#  ('journey', 26),
#  ('city', 36),
#  ('mirchigadh', 1),
#  ('little', 15),
#  ('singham', 4),
#  ('vies', 2),
#  ('title', 5),
#  ('ultimate', 5),
#  ('warrior', 6),
#  ('fights', 10),
#  ('zombie', 2),
#  ('king', 16),
#  ('army', 8),
#  ('traumatic', 6),
#  ('event', 5),
#  ('indigenous', 1),
#  ('vancouver', 1),
#  ('form', 13),
#  ('deep', 13),
#  ('bond', 14),
#  ('despite', 7),
#  ('leading', 6),
#  ('different', 16),
#  ('hit', 16),
#  ('frank', 3),
#  ('sheeran', 1),
#  ('looks', 9),
#  ('secrets', 21),
#  ('kept', 1),
#  ('loyal', 4),
#  ('member', 5),
#  ('bufalino', 1),
#  ('crime', 35),
#  ('family', 112),
#  ('acclaimed', 2),
#  ('martin', 5),
#  ('scorsese', 2),
#  ('comedian', 13),
#  ('mike', 6),
#  ('birbiglia', 2),
#  ('hits', 8),
#  ('broadway', 2),
#  ('hilarious', 9),
#  ('yet', 6),
#  ('profound', 2),
#  ('one-man', 1),
#  ('recounts', 4),
#  ('emotional', 7),
#  ('physical', 7),
#  ('parenthood', 1),
#  ('eve', 5),
#  ('pitchfork', 2),
#  ('pines', 3),
#  ('super', 7),
#  ('monsters', 7),
#  ('joining', 3),
#  ('deck', 1),
#  ('halls', 1),
#  ('find', 67),
#  ('santa', 4),
#  ('reindeer', 2),
#  ('save', 55),
#  ('ice', 2),
#  ('crystal', 5),
#  ('frosty', 2),
#  ('realm', 2),
#  ('freezing', 1),
#  ('rainbow', 3),
#  ('kingdom', 11),
#  ('citizens', 3),
#  ('winter', 5),
#  ('wishfest', 1),
#  ('assortment', 1),
#  ('talent', 9),
#  ('takes', 58),
#  ('stage', 15),
#  ('honest', 3),
#  ('stand-up', 26),
#  ('featuring', 13),
#  ('mexico', 14),
#  ('funniest', 2),
#  ('lgbtq', 2),
#  ('businesswoman', 2),
#  ('debra', 1),
#  ('newell', 1),
#  ('unravels', 5),
#  ('lies', 6),
#  ('manipulation', 1),
#  ('con', 10),
#  ('john', 6),
#  ('meehan', 1),
#  ('true-crime', 1),
#  ('podcast', 1),
#  ('aspiring', 17),
#  ('fulfill', 6),
#  ('dream', 14),
#  ('become', 33),
#  ('civil', 6),
#  ('services', 2),
#  ('officer', 17),
#  ('loses', 9),
#  ('way', 30),
#  ('upon', 8),
#  ('becoming', 13),
#  ('entangled', 3),
#  ('criminal', 17),
#  ('lynchpin', 1),
#  ('extensive', 1),
#  ('interviews', 15),
#  ('documentary', 71),
#  ('critical', 1),
#  ('look', 12),
#  ('gender', 4),
#  ('inequality', 1),
#  ('spain', 12),
#  ('feminist', 1),
#  ('movement', 6),
#  ('aims', 2),
#  ('shift', 1),
#  ('accident', 16),
#  ('leaves', 15),
#  ('recollection', 1),
#  ('prime', 6),
#  ('suspect', 5),
#  ('search', 25),
#  ('serial', 9),
#  ('killer', 23),
#  ('targeting', 2),
#  ('storm', 5),
#  ('wrecks', 1),
#  ('ship', 5),
#  ('super-strong', 1),
#  ('sailor', 1),
#  ('popeye', 1),
#  ('washes', 1),
#  ('ashore', 1),
#  ('winds', 4),
#  ('rooming', 1),
#  ('oyl', 1),
#  ('household', 2),
#  ('meets', 22),
#  ('olive', 1),
#  ('trying', 20),
#  ('go', 20),
#  ('straight', 4),
#  ('once-successful', 1),
#  ('businessman', 10),
#  ('fresh', 4),
#  ('prison', 20),
#  ('forced', 20),
#  ('orchestrate', 2),
#  ('brazen', 2),
#  ('born', 5),
#  ('supernatural', 11),
#  ('strength', 6),
#  ('bong-soon', 1),
#  ('evil', 27),
#  ('procures', 1),
#  ('justice', 9),
#  ('getting', 10),
#  ('triangle', 10),
#  ('ceo', 3),
#  ('boss', 11),
#  ('cop', 25),
#  ('crush', 6),
#  ('follow', 9),
#  ('adventures', 13),
#  ('wilbur', 1),
#  ('pig', 2),
#  ('templeton', 1),
#  ('rat', 1),
#  ('charlotte', 1),
#  ('spider', 2),
#  ('musical', 8),
#  ('version', 4),
#  ('e.b', 1),
#  ('white', 5),
#  ('timeless', 3),
#  ('officers', 8),
#  ('taylor', 2),
#  ('zavala', 1),
#  ('patrol', 4),
#  ('streets', 5),
#  ('central', 5),
#  ('los', 7),
#  ('angeles', 5),
#  ('area', 3),
#  ('ruled', 2),
#  ('gangs', 2),
#  ('riddled', 2),
#  ('drug', 30),
#  ('violence', 5),
#  ('vietnam', 2),
#  ('horrors', 1),
#  ('brutally', 2),
#  ('eyes', 3),
#  ('american', 21),
#  ('soldiers', 3),
#  ('take', 52),
#  ('heavily', 2),
#  ('fortified', 1),
#  ('hill', 3),
#  ('vietcong', 1),
#  ('control', 17),
#  ('nine', 1),
#  ('continents', 1),
#  ('face', 20),
#  ('crisis', 13),
#  ('disciple', 1),
#  ('joins', 23),
#  ('spirit', 15),
#  ('blade', 2),
#  ('sect', 1),
#  ('comes', 21),
#  ('tutelage', 1),
#  ('temperamental', 1),
#  ('sage', 1),
#  ('h.g', 1),
#  ('wells', 1),
#  ('classic', 15),
#  ('follows', 33),
#  ('scientist', 7),
#  ('inventor', 1),
#  ('determined', 23),
#  ('doubters', 1),
#  ('travel', 14),
#  ('possible', 3),
#  ('thrust', 2),
#  ('violent', 9),
#  ('home', 67),
#  ('custody', 4),
#  ('center', 8),
#  ('teenager', 7),
#  ('navigate', 13),
#  ('tough', 8),
#  ('forge', 3),
#  ('unlikely', 13),
#  ('alliances', 1),
#  ('survive', 13),
#  ('gets', 48),
#  ('angry', 1),
#  ('middle', 8),
#  ('schooler', 4),
#  ('naoko', 1),
#  ('fierce', 6),
#  ('dinosaur', 2),
#  ('gauko', 1),
#  ('thanks', 3),
#  ('aliens', 5),
#  ('full', 10),
#  ('wacky', 5),
#  ('incidents', 2),
#  ('eight', 8),
#  ('stories', 33),
#  ('celebrating', 2),
#  ('faith', 9),
#  ('forgiveness', 2),
#  ('inspired', 17),
#  ('dolly', 1),
#  ('parton', 1),
#  ('country', 14),
#  ('music', 26),
#  ('catalog', 1),
#  ('girls', 10),
#  ('ōarai', 1),
#  ('high', 44),
#  ('formidable', 2),
#  ('university', 4),
#  ('tank', 1),
#  ('battle', 23),
#  ('avoid', 6),
#  ('closure', 1),
#  ('school', 79),
#  ('performs', 2),
#  ('live', 17),
#  ('concert', 5),
#  ('special', 48),
#  ('features', 5),
#  ('riotous', 1),
#  ('selection', 1),
#  ('unique', 9),
#  ('insights', 8),
#  ('observations', 2),
#  ('culled', 1),
#  ('diary', 1),
#  ('ride', 5),
#  ('along', 7),
#  ('police', 23),
#  ('smugglers', 3),
#  ('toe-to-toe', 1),
#  ('outwit', 1),
#  ('locales', 1),
#  ('around', 22),
#  ('guardian', 6),
#  ('angelus', 2),
#  ('secret', 32),
#  ('behind', 41),
#  ('system', 7),
#  ('bureaucracy', 2),
#  ('leads', 23),
#  ('break', 11),
#  ('official', 3),
#  ('rules', 7),
#  ('protecting', 5),
#  ('humans', 9),
#  ('vintage', 3),
#  ('footage', 14),
#  ('traces', 7),
#  ('icon', 3),
#  ('carroll', 1),
#  ('shelby', 1),
#  ('reinvention', 3),
#  ('farmer', 3),
#  ('racer', 4),
#  ('entrepreneur', 7),
#  ('peer', 1),
#  ('singaporeans', 1),
#  ('defy', 3),
#  ('expectations', 3),
#  ('traverse', 2),
#  ('tricky', 1),
#  ('terrain', 3),
#  ('career', 26),
#  ('board', 2),
#  ('russia', 3),
#  ('first', 33),
#  ('nuclear', 5),
#  ('ballistic', 1),
#  ('submarine', 3),
#  ('capt', 2),
#  ('vostrikov', 1),
#  ('race', 19),
#  ('prevent', 3),
#  ('chernobyl-like', 1),
#  ('explosion', 2),
#  ('making', 9),
#  ('deal', 7),
#  ('figure', 8),
#  ('schoolers', 1),
#  ('emerge', 4),
#  ('powers', 14),
#  ('join', 14),
#  ('solve', 12),
#  ('murder', 39),
#  ('medieval', 3),
#  ('magic', 10),
#  ('sends', 9),
#  ('14th-century', 1),
#  ('knight', 4),
#  ('modern-day', 4),
#  ('ohio', 4),
#  ('science', 8),
#  ('teacher', 12),
#  ('disillusioned', 2),
#  ('lifelong', 6),
#  ('roz', 1),
#  ('lil', 1),
#  ('fall', 12),
#  ('teenage', 20),
#  ('sons', 4),
#  ('carry', 3),
#  ('affairs', 4),
#  ('relative', 1),
#  ('secrecy', 1),
#  ('living', 23),
#  ('roof', 4),
#  ('group', 54),
#  ('unabashed', 1),
#  ('wrestle', 1),
#  ('everyday', 8),
#  ('issues', 8),
#  ('financial', 6),
#  ('woes', 3),
#  ('shared', 2),
#  ('quarters', 1),
#  ('romantic', 12),
#  ('misfires', 1),
#  ('escape', 11),
#  ('stress', 3),
#  ('fame', 10),
#  ('teen', 46),
#  ('pop', 7),
#  ('jordan', 3),
#  ('incognito', 1),
#  ('small', 13),
#  ('town', 29),
#  ('forms', 4),
#  ('art', 14),
#  ('emily', 2),
#  ('realizing', 1),
#  ('boob', 1),
#  ('tube', 1),
#  ('gone', 6),
#  ('beavis', 1),
#  ('butt-head', 1),
#  ('expedition', 1),
#  ('vegas', 8),
#  ('nation', 7),
#  ('capital', 1),
#  ('ladies', 3),
#  ('robin', 4),
#  ('jamika', 1),
#  ('head', 8),
#  ('heels', 3),
#  ('greets', 1),
#  ('surprises', 6),
#  ('son', 55),
#  ('bebe', 1),
#  ('charts', 4),
#  ('rise', 16),
#  ('hot', 7),
#  ('yoga', 3),
#  ('founder', 2),
#  ('bikram', 1),
#  ('choudhury', 1),
#  ('global', 9),
#  ('empire', 7),
#  ('disturbing', 4),
#  ('revelations', 2),
#  ('light', 8),
#  ('lazarus', 2),
#  ('finds', 60),
#  ('rae', 1),
#  ('beaten', 2),
#  ('near', 1),
#  ('death', 46),
#  ('acts', 1),
#  ('help', 77),
#  ('redeem', 1),
#  ('saving', 5),
#  ('anyone', 4),
#  ('demons', 12),
#  ('lethal', 4),
#  ('virus', 5),
#  ('spreads', 2),
#  ('globally', 1),
#  ('seek', 7),
#  ('reputed', 1),
#  ('plague-free', 1),
#  ('avoiding', 1),
#  ('infected', 1),
#  ('travelers', 2),
#  ('turn', 24),
#  ('one', 83),
#  ('another', 17),
#  ('village', 21),
#  ('educated', 1),
#  ('commoner', 1),
#  ('budding', 5),
#  ('forbidden', 5),
#  ('worth', 3),
#  ('resisting', 1),
#  ('repressive', 1),
#  ('social', 21),
#  ('hierarchy', 2),
#  ('riveting', 1),
#  ('doc', 1),
#  ('bill', 5),
#  ('confronts', 4),
#  ('america', 17),
#  ('judicial', 1),
#  ('falsely', 2),
#  ('sentenced', 2),
#  ('40', 2),
#  ('years', 51),
#  ('community', 9),
#  ('college', 37),
#  ('geology', 1),
#  ('professors', 1),
#  ('microscopic', 1),
#  ('alien', 7),
#  ('life-forms', 1),
#  ('meteorite', 1),
#  ('military', 6),
#  ('involved', 7),
#  ('grieving', 8),
#  ('mother', 56),
#  ('karen', 2),
#  ('mccann', 2),
#  ('hands', 8),
#  ('raped', 3),
#  ('murdered', 11),
#  ('freed', 2),
#  ('technicality', 1),
#  ('reunion', 6),
#  ('gateway', 1),
#  ('three-part', 1),
#  ('explores', 10),
#  ('intimate', 10),
#  ('complexities', 1),
#  ('history', 23),
#  ('andy', 2),
#  ('samberg', 1),
#  ('stars', 16),
#  ('comedy', 33),
#  ('accident-prone', 1),
#  ('daredevil', 3),
#  ('jump', 2),
#  ('15', 2),
#  ('buses', 1),
#  ('moped', 1),
#  ('impress', 3),
#  ('abusive', 9),
#  ('stepfather', 1),
#  ('olsen', 1),
#  ('twins', 7),
#  ('put', 15),
#  ('cute', 1),
#  ('mark', 3),
#  ('twain', 1),
#  ('tale', 11),
#  ('prince', 8),
#  ('pauper', 1),
#  ('playing', 8),
#  ('identical', 3),
#  ('9-year-olds', 1),
#  ('backgrounds', 3),
#  ('orphaned', 3),
#  ('amanda', 1),
#  ('alyssa', 1),
#  ('lorena', 1),
#  ('ramírez', 1),
#  ('rarámuri', 1),
#  ('pastoral', 1),
#  ('except', 2),
#  ('straps', 1),
#  ('sandals', 1),
#  ('compete', 10),
#  ('ultramarathon', 1),
#  ('runner', 1),
#  ('childhood', 20),
#  ('pals', 11),
#  ('rosie', 1),
#  ('alex', 2),
#  ('struggle', 16),
#  ('resolve', 1),
#  ('lasting', 3),
#  ('self-trained', 1),
#  ('engineer', 4),
#  ('risks', 4),
#  ('debt', 10),
#  ('reputation', 3),
#  ('quest', 14),
#  ('improve', 1),
#  ('grueling', 1),
#  ('work', 18),
#  ('conditions', 6),
#  ('weaving', 1),
#  ('epic', 8),
#  ('spaghetti', 1),
#  ('western', 1),
#  ('flinty', 1),
#  ('gunslinger', 1),
#  ('hired', 14),
#  ('railroad', 2),
#  ('tycoon', 6),
#  ('kill', 8),
#  ('standing', 2),
#  ('trans-american', 1),
#  ('iron', 3),
#  ('horse', 4),
#  ('average-guy', 1),
#  ('kirk', 2),
#  ('starts', 16),
#  ('dating', 9),
#  ('drop-dead-gorgeous', 1),
#  ('molly', 2),
#  ("n't", 21),
#  ('see', 10),
#  ('losing', 10),
#  ('socially', 2),
#  ('awkward', 6),
#  ('catholic', 4),
#  ('schoolgirl', 1),
#  ('vows', 6),
#  ('dreamy', 2),
#  ('classmate', 6),
#  ('affections', 2),
#  ('taking', 17),
#  ('prize', 5),
#  ('upcoming', 1),
#  ('3-d', 1),
#  ('motion', 2),
#  ('capture', 5),
#  ('adapts', 1),
#  ('georges', 1),
#  ('remi', 1),
#  ('comic', 15),
#  ('strip', 6),
#  ('fearless', 4),
#  ('journalist', 7),
#  ('tintin', 1),
#  ('trusty', 3),
#  ('dog', 9),
#  ('snowy', 1),
#  ('spooky', 3),
#  ('grisly', 2),
#  ('thriller', 9),
#  ('truth', 21),
#  ('claims', 3),
#  ('killed', 9),
#  ('people', 30),
#  ('exorcism', 3),
#  ('following', 11),
#  ('friend', 34),
#  ('suicide', 5),
#  ('husband', 28),
#  ('dumps', 2),
#  ('younger', 5),
#  ('model', 5),
#  ('plot', 8),
#  ('payback', 1),
#  ('two-timing', 1),
#  ('exes', 1),
#  ('authorities', 5),
#  ('drowned', 1),
#  ('body', 10),
#  ('small-town', 9),
#  ('psychic', 6),
#  ('visions', 6),
#  ('committed', 3),
#  ('rescue', 20),
#  ('flagging', 1),
#  ('car', 15),
#  ('dealership', 1),
#  ('major', 11),
#  ('sale', 2),
#  ('fast-talking', 2),
#  ('closer', 5),
#  ('spends', 2),
#  ('days', 17),
#  ('lot', 3),
#  ('nights', 2),
#  ('local', 12),
#  ('clubs', 1),
#  ('washed-up', 4),
#  ('professional', 9),
#  ('quarterback', 4),
#  ('paul', 5),
#  ('crewe', 1),
#  ('sent', 8),
#  ('jail', 6),
#  ('inmate', 2),
#  ('gridiron', 1),
#  ('guards', 1),
#  ('raised', 8),
#  ('ashram', 1),
#  ('india', 22),
#  ('self-styled', 1),
#  ('guru', 1),
#  ('returns', 33),
#  ('native', 7),
#  ('settle', 7),
#  ('rivalry', 6),
#  ('pro', 1),
#  ('hockey', 3),
#  ('players', 6),
#  ('attorney', 5),
#  ('scrappy', 3),
#  ('paralegal', 1),
#  ('parents', 14),
#  ('terminally', 5),
#  ('ill', 8),
#  ('boy', 31),
#  ('suit', 3),
#  ('insurance', 3),
#  ('company', 13),
#  ('backwater', 1),
#  ('iowa', 1),
#  ('gilbert', 1),
#  ('torn', 3),
#  ('care', 12),
#  ('troubled', 8),
#  ('possibilities', 2),
#  ('4-year-old', 1),
#  ('twisting', 1),
#  ('arduous', 3),
#  ('identify', 1),
#  ('frustratingly', 1),
#  ('elusive', 2),
#  ('treacherous', 3),
#  ('dedicated', 5),
#  ('rescuers', 1),
#  ('struggles', 18),
#  ('survived', 2),
#  ('trade', 3),
#  ('tragic', 10),
#  ('collapse', 4),
#  ('divorced', 4),
#  ('writer', 18),
#  ('letter', 3),
#  ('old', 33),
#  ('boyfriend', 11),
#  ('announcing', 1),
#  ('wife', 42),
#  ('baby', 6),
#  ('hometown', 15),
#  ('reconnect', 4),
#  ('ex', 4),
#  ...]

# %%
## Creating a list of the polarity of the descriptions of various content added in 2019
a=[]
for i in blob.sentences:
    a.append(i.polarity)
print(a)
# Out:
# [0.08333333333333333, 0.025000000000000005, 0.41666666666666663, 0.17083333333333336, -0.1, 0.3, 0.25, 0.45, -0.35, 0.5, -0.15000000000000002, 0.0, -0.22499999999999998, 0.0, 0.0, 0.0, -0.3875, 0.0, 0.2, 0.2090909090909091, 0.26666666666666666, 0.7, 0.6, 0.29583333333333334, 0.0, -0.0625, 0.0, 0.16666666666666666, 0.14583333333333334, 0.04166666666666666, 0.0, 0.35, 0.6, 0.0, 0.0, -0.037500000000000006, 0.0, 0.1, 0.0, 0.06666666666666665, -0.11111111111111112, 0.0, 0.0, 0.0, -0.35833333333333334, 0.1, 0.0, 0.08333333333333333, -0.4212542087542088, -0.25, 0.38749999999999996, 0.5, 0.16, 0.2895021645021645, -0.125, -0.22121212121212122, 0.0, 0.1, 0.25, 0.0, 0.21999999999999997, 0.29000000000000004, 0.05500000000000001, -0.05, 0.06678571428571428, 0.0, 0.0, 0.030000000000000006, 0.1, 0.6, 0.0, 0.0, 0.2333333333333333, -0.10000000000000003, -0.175, 0.6, -0.024999999999999994, 0.0, 0.2606060606060606, 0.0, 0.025000000000000005, 0.5, 0.05, 0.0, 0.11250000000000002, 0.1722222222222222, -0.30000000000000004, 0.0, -0.1, 0.03125, -0.10000000000000002, 0.25, -0.2, -0.08787878787878789, -0.21666666666666667, -0.425, 0.1, 0.0, -0.05000000000000001, 0.0, 0.0, 0.35, 0.425, -0.37121212121212127, -0.15000000000000002, 0.0, 0.575, 0.03333333333333333, -0.2, 0.24500000000000002, 0.1, 0.2, 0.0, -0.15, -0.1, 0.2, 0.14208333333333334, 0.1481818181818182, -0.2583333333333333, -0.23333333333333328, 0.5375, 0.215, -0.011111111111111117, 0.0, 0.26666666666666666, 0.19666666666666668, 0.14166666666666666, -0.2, 0.0, 0.33, 0.3, 0.06534090909090909, 0.302, 0.4, 0.4, 0.20833333333333334, 0.03125, 0.13636363636363635, 0.06818181818181818, 0.375, 0.08910533910533909, 0.6000000000000001, -0.03799999999999999, 0.1, 0.25, -0.11666666666666665, -0.6166666666666667, -0.09583333333333334, 0.3, 0.5, 0.09999999999999999, 0.09999999999999998, 0.08333333333333334, 0.041666666666666664, 0.03999999999999999, 0.7, 0.0, 0.27199999999999996, 0.24318181818181817, -0.30000000000000004, 0.2, 0.32222222222222224, 0.05, -0.75, 0.19999999999999998, 0.58, -0.04999999999999999, -0.07777777777777779, 0.08333333333333333, 0.13954545454545456, 0.11249999999999999, 0.175, -0.3499999999999999, -0.30000000000000004, -0.4, -0.12121212121212122, -1.0, 0.38, 0.11666666666666665, 0.0, 0.21666666666666667, 0.04323232323232324, 0.1, 0.8, -0.06272727272727273, 0.0, 0.0, -0.1, -0.18, 0.35, 0.0, 0.2333333333333333, 0.2857142857142857, 0.25, 0.0, -0.14583333333333331, 0.0, 0.10079365079365078, 0.0, 0.0, 0.35000000000000003, 0.12, 0.0, -0.29500000000000004, 0.0, 0.1, -0.2977777777777778, 0.5, 0.0, 0.4333333333333333, -0.45, 0.3833333333333333, 0.5, 0.5, -0.125, 0.3, -0.04999999999999999, 0.5, 0.0, -0.05625, 0.0, 0.0, 0.06818181818181818, 0.0, 0.13636363636363635, 0.0, 0.16666666666666666, 0.16666666666666669, 0.6, 0.4666666666666667, 0.0, 0.19999999999999998, 0.09545454545454546, -0.05555555555555555, 0.03666666666666667, 0.1, -0.4, -0.25, 0.04999999999999999, 0.0, 0.0, 0.05, 0.0, 0.3333333333333333, -0.2, 0.0, 0.21481481481481482, -0.1475378787878788, 0.5, 0.4666666666666667, 0.126984126984127, 0.16, 0.16666666666666666, 0.55, 0.0, -0.09999999999999999, 0.0, 0.3666666666666667, -0.2, 0.0, -0.03465909090909092, -0.05681818181818182, 0.11818181818181818, 0.15499999999999997, 0.0, 0.0, 0.0, -0.15000000000000002, 0.1111111111111111, 0.3, 0.06666666666666667, -0.1, 0.0, 0.0, 0.13636363636363635, 0.25, 0.0, 0.35, 0.0, 0.1, -0.075, 0.1, 0.3, 0.0, 0.39999999999999997, 0.7, 0.175, -0.15555555555555559, 0.3, 0.0, -0.125, 0.2017857142857143, 0.35, -0.125, 0.26666666666666666, 0.0, 0.5, 0.0, 0.0, 0.15833333333333333, -0.525, 0.06666666666666665, 0.0, -0.16666666666666666, 0.35714285714285715, 0.3833333333333333, 0.0, 0.13636363636363635, 0.5125, 0.5, 0.0, 0.4333333333333333, -0.09047619047619049, 0.13333333333333333, -0.1625, 0.4, 0.22000000000000003, -0.4, 0.05555555555555555, 0.0, 1.0, -0.10000000000000002, -0.08333333333333333, 0.0, 0.0, 0.28571428571428575, -0.3666666666666667, 0.3181818181818182, 0.175, ...

# %%
plt.plot(df_19.index[:20],a[:20], color='blue', marker='*',linewidth=1)
# add a title
plt.title("Sentiment for various content added in 2019 based on index")
# add a label to the y-axis
plt.ylabel("Sentiment")
plt.xlabel("Index")
plt.show()

# %%
sorted_items = sorted(items, key=itemgetter(1), reverse=True)
top20 = sorted_items[0:20]
top20
# Out:
# [('life', 176),
#  ('young', 139),
#  ('new', 127),
#  ('man', 126),
#  ('family', 112),
#  ('two', 106),
#  ('world', 102),
#  ('woman', 100),
#  ('love', 99),
#  ('friends', 83),
#  ('one', 83),
#  ('must', 81),
#  ('school', 79),
#  ('help', 77),
#  ('documentary', 71),
#  ('series', 69),
#  ('father', 67),
#  ('find', 67),
#  ('home', 67),
#  ('lives', 61)]

# %%
d= pd.DataFrame(top20, columns=['word', 'count'])
axes = d.plot.bar(x='word', y='count', legend=False,color = 'green')
plt.xlabel('Most Common Words')
plt.ylabel('Frequency')
plt.title('Most Common Words from content added in 2019')
plt.gcf().tight_layout()

# %%
summary_2=list(df_18['description'])
summary_2=' '.join(summary_2)
summary_2
# Out:
# 'Bill Hicks remembers a wild night in 1989 and offers his views on puffing cigarettes, smoking weed, drinking, sex, commercials and music. This documentary about comedian Bill Hicks offers insight into his irreverent takes on, well, everything. Brother Steve Hicks is the star witness. In one of his most iconic performances, late comedian Bill Hicks demonstrates what made him such a singular talent and a force to be reckoned with. In his final recorded special, the iconoclastic comedian channels Goat Boy and tackles provocative topics like British porn, pot and the priesthood. Filmed in 1989 at a turning point in comedian Bill Hicks\'s career, this rare onstage performance captures him spouting off on a variety of topics. Late-night talk show host Conan O\'Brien hits the road in this special that brings him and his sense of humor to far-flung destinations. Frisbee national champion Brodie Smith challenges inventive athletes across the US to an exhibition match in the unconventional sports they\'ve created. British comic Gina Yashere takes the stage in San Francisco, where she shares her thoughts on everything from toilet ninjas to her troublesome name. Standup comedian and "Daily Show" correspondent Gina Yashere delivers a sharp set of wry observations on the environment, money and more. Self-made social media celebrities share the stories of how they built their online empires and where they plan to take their unexpected fame next. When street vices keep them coming back, three prisoners make sense of their lives in a penitentiary – and beyond it – through rap. The one-time preacher shakes and shudders as he tears into subjects including sex, marriage, religion, drugs and famine in this HBO special. Comic Sam Kinison lets it rip with this performance at L.A.\'s Wiltern theatre, skewering every segment of modern society from religion to television. Standup legend Sam Kinison is at his screaming best as he storms the stage in Sin City to get a few things off his chest. Sam\'s brother and former manager Bill Kinison speaks about the late comedian\'s journey from preacher to standup legend. When three teen outcasts arrive at a hot springs hotel to help run things, creepy incidents prompt comical efforts to find what lurks in their midst. Welcome to the irreverent world of Robert Hall – aka Slobby Robby – a pop culture junkie who buys and sells collectable goods from the \'80s and \'90s. Taylor Swift takes the stage in Dallas for the reputation Stadium Tour and celebrates a monumental night of music, memories and visual magic. This documentary highlights spontaneous encounters with the elusive, comedic veteran, who touches lives by simply showing up anywhere. The Seven Deadly Sins aid the Sky People against a powerful group of demons hellbent on resurrecting a demonic beast sealed over 3,000 years ago. Standup comedian Tim Allen delivers a set dedicated to "men stuff" like lawn care, power tools and why he grunts like an animal. Standup star Tim Allen storms the stage for a set chock-full of observations about powerful cars, beautiful lawns and more of the things he loves. Flanked by a full orchestra, Tim Minchin takes the Royal Albert Hall by storm with a wonderfully witty evening of satirical musical comedy. Comedic pianist Tim Minchin performs a host of his catchy songs that touch on everything from the Middle East to the healing power of canvas bags. Standup comedian Todd Glass gets right down to it, with sly observations on accepting directions, denying compliments and being afraid of the dark. Comedian Tom Papa riffs on the trials of married life, fatherhood in the 21st century, domestic pets and more in his stand-up show. This third installment in a documentary series examines the lives of the adult film genre\'s biggest stars after their industry careers have ended. After a popular professor is attacked on a New York street, the story of how a series of intertwined events led to the life-altering assault unfolds. This colle ...

# %%
blob_2= TextBlob(summary_2)

# %%
items=blob_2.word_counts.items()
items=[item for item in items if item[0] not in stop_words ]
items
# Out:
# [('bill', 8),
#  ('hicks', 5),
#  ('remembers', 2),
#  ('wild', 12),
#  ('night', 18),
#  ('1989', 3),
#  ('offers', 6),
#  ('views', 4),
#  ('puffing', 1),
#  ('cigarettes', 2),
#  ('smoking', 2),
#  ('weed', 2),
#  ('drinking', 2),
#  ('sex', 23),
#  ('commercials', 2),
#  ('music', 26),
#  ('documentary', 64),
#  ('comedian', 44),
#  ('insight', 1),
#  ('irreverent', 7),
#  ('takes', 53),
#  ('well', 6),
#  ('everything', 23),
#  ('brother', 29),
#  ('steve', 3),
#  ('star', 29),
#  ('witness', 3),
#  ('one', 70),
#  ('iconic', 8),
#  ('performances', 5),
#  ('late', 9),
#  ('demonstrates', 3),
#  ('made', 9),
#  ('singular', 1),
#  ('talent', 4),
#  ('force', 19),
#  ('reckoned', 2),
#  ('final', 12),
#  ('recorded', 2),
#  ('special', 34),
#  ('iconoclastic', 2),
#  ('channels', 2),
#  ('goat', 2),
#  ('boy', 28),
#  ('tackles', 2),
#  ('provocative', 2),
#  ('topics', 7),
#  ('like', 13),
#  ('british', 15),
#  ('porn', 3),
#  ('pot', 4),
#  ('priesthood', 1),
#  ('filmed', 2),
#  ('turning', 6),
#  ('point', 8),
#  ('career', 26),
#  ('rare', 6),
#  ('onstage', 4),
#  ('performance', 9),
#  ('captures', 5),
#  ('spouting', 1),
#  ('variety', 4),
#  ('late-night', 3),
#  ('talk', 6),
#  ('show', 35),
#  ('host', 12),
#  ('conan', 1),
#  ("o'brien", 1),
#  ('hits', 11),
#  ('road', 8),
#  ('brings', 14),
#  ('sense', 8),
#  ('humor', 7),
#  ('far-flung', 1),
#  ('destinations', 1),
#  ('frisbee', 1),
#  ('national', 7),
#  ('champion', 6),
#  ('brodie', 1),
#  ('smith', 3),
#  ('challenges', 15),
#  ('inventive', 1),
#  ('athletes', 6),
#  ('across', 13),
#  ('us', 3),
#  ('exhibition', 3),
#  ('match', 9),
#  ('unconventional', 3),
#  ('sports', 6),
#  ('created', 1),
#  ('comic', 22),
#  ('gina', 2),
#  ('yashere', 2),
#  ('stage', 17),
#  ('san', 2),
#  ('francisco', 1),
#  ('shares', 8),
#  ('thoughts', 4),
#  ('toilet', 3),
#  ('ninjas', 1),
#  ('troublesome', 1),
#  ('name', 7),
#  ('standup', 6),
#  ('daily', 7),
#  ('correspondent', 1),
#  ('delivers', 9),
#  ('sharp', 3),
#  ('set', 30),
#  ('wry', 2),
#  ('observations', 5),
#  ('environment', 1),
#  ('money', 11),
#  ('self-made', 1),
#  ('social', 23),
#  ('media', 11),
#  ('celebrities', 6),
#  ('share', 15),
#  ('stories', 33),
#  ('built', 4),
#  ('online', 10),
#  ('empires', 3),
#  ('plan', 20),
#  ('take', 36),
#  ('unexpected', 19),
#  ('fame', 12),
#  ('next', 11),
#  ('street', 6),
#  ('vices', 1),
#  ('keep', 16),
#  ('coming', 5),
#  ('back', 37),
#  ('three', 58),
#  ('prisoners', 4),
#  ('make', 30),
#  ('lives', 52),
#  ('penitentiary', 2),
#  ('beyond', 6),
#  ('rap', 5),
#  ('one-time', 1),
#  ('preacher', 4),
#  ('shakes', 1),
#  ('shudders', 1),
#  ('tears', 2),
#  ('subjects', 1),
#  ('including', 7),
#  ('marriage', 30),
#  ('religion', 3),
#  ('drugs', 4),
#  ('famine', 1),
#  ('hbo', 1),
#  ('sam', 5),
#  ('kinison', 3),
#  ('lets', 1),
#  ('rip', 1),
#  ('l.a', 4),
#  ('wiltern', 1),
#  ('theatre', 1),
#  ('skewering', 1),
#  ('every', 9),
#  ('segment', 1),
#  ('modern', 11),
#  ('society', 11),
#  ('television', 3),
#  ('legend', 7),
#  ('screaming', 1),
#  ('best', 29),
#  ('storms', 3),
#  ('sin', 1),
#  ('city', 46),
#  ('get', 37),
#  ('things', 22),
#  ('chest', 2),
#  ('former', 29),
#  ('manager', 7),
#  ('speaks', 4),
#  ('journey', 17),
#  ('teen', 31),
#  ('outcasts', 1),
#  ('arrive', 5),
#  ('hot', 4),
#  ('springs', 1),
#  ('hotel', 9),
#  ('help', 44),
#  ('run', 20),
#  ('creepy', 2),
#  ('incidents', 2),
#  ('prompt', 1),
#  ('comical', 1),
#  ('efforts', 7),
#  ('find', 65),
#  ('lurks', 2),
#  ('midst', 1),
#  ('welcome', 4),
#  ('world', 98),
#  ('robert', 5),
#  ('hall', 3),
#  ('aka', 2),
#  ('slobby', 1),
#  ('robby', 1),
#  ('pop', 8),
#  ('culture', 14),
#  ('junkie', 1),
#  ('buys', 1),
#  ('sells', 2),
#  ('collectable', 1),
#  ('goods', 1),
#  ('80s', 2),
#  ('90s', 2),
#  ('taylor', 1),
#  ('swift', 1),
#  ('dallas', 1),
#  ('reputation', 4),
#  ('stadium', 1),
#  ('tour', 10),
#  ('celebrates', 2),
#  ('monumental', 1),
#  ('memories', 11),
#  ('visual', 3),
#  ('magic', 10),
#  ('highlights', 4),
#  ('spontaneous', 1),
#  ('encounters', 11),
#  ('elusive', 4),
#  ('comedic', 4),
#  ('veteran', 6),
#  ('touches', 3),
#  ('simply', 4),
#  ('showing', 1),
#  ('anywhere', 2),
#  ('seven', 8),
#  ('deadly', 15),
#  ('sins', 1),
#  ('aid', 2),
#  ('sky', 2),
#  ('people', 22),
#  ('powerful', 24),
#  ('group', 38),
#  ('demons', 3),
#  ('hellbent', 1),
#  ('resurrecting', 2),
#  ('demonic', 2),
#  ('beast', 2),
#  ('sealed', 2),
#  ('3,000', 2),
#  ('years', 51),
#  ('ago', 6),
#  ('tim', 6),
#  ('allen', 2),
#  ('dedicated', 3),
#  ('men', 29),
#  ('stuff', 1),
#  ('lawn', 1),
#  ('care', 6),
#  ('power', 19),
#  ('tools', 1),
#  ('grunts', 1),
#  ('animal', 7),
#  ('chock-full', 2),
#  ('cars', 3),
#  ('beautiful', 10),
#  ('lawns', 1),
#  ('loves', 8),
#  ('flanked', 1),
#  ('full', 8),
#  ('orchestra', 1),
#  ('minchin', 2),
#  ('royal', 6),
#  ('albert', 1),
#  ('storm', 3),
#  ('wonderfully', 1),
#  ('witty', 1),
#  ('evening', 4),
#  ('satirical', 1),
#  ('musical', 11),
#  ('comedy', 41),
#  ('pianist', 5),
#  ('performs', 9),
#  ('catchy', 2),
#  ('songs', 6),
#  ('touch', 2),
#  ('middle', 4),
#  ('east', 3),
#  ('healing', 3),
#  ('canvas', 1),
#  ('bags', 2),
#  ('todd', 2),
#  ('glass', 2),
#  ('gets', 19),
#  ('right', 6),
#  ('sly', 2),
#  ('accepting', 2),
#  ('directions', 3),
#  ('denying', 1),
#  ('compliments', 1),
#  ('afraid', 2),
#  ('dark', 28),
#  ('tom', 4),
#  ('papa', 1),
#  ('riffs', 2),
#  ('trials', 2),
#  ('married', 7),
#  ('life', 136),
#  ('fatherhood', 5),
#  ('21st', 2),
#  ('century', 4),
#  ('domestic', 5),
#  ('pets', 2),
#  ('stand-up', 35),
#  ('third', 3),
#  ('installment', 1),
#  ('series', 53),
#  ('examines', 6),
#  ('adult', 5),
#  ('film', 40),
#  ('genre', 2),
#  ('biggest', 10),
#  ('stars', 11),
#  ('industry', 6),
#  ('careers', 2),
#  ('ended', 1),
#  ('popular', 8),
#  ('professor', 6),
#  ('attacked', 2),
#  ('new', 113),
#  ('york', 12),
#  ('story', 38),
#  ('intertwined', 4),
#  ('events', 16),
#  ('led', 3),
#  ('life-altering', 2),
#  ('assault', 4),
#  ('unfolds', 4),
#  ('collection', 6),
#  ('restores', 1),
#  ('films', 5),
#  ('women', 37),
#  ('tackled', 1),
#  ('hot-button', 1),
#  ('issues', 9),
#  ('transcended', 1),
#  ('norms', 2),
#  ('left', 11),
#  ('mark', 5),
#  ('history', 21),
#  ('cinema', 2),
#  ('father-son', 1),
#  ('team', 34),
#  ('small-town', 5),
#  ('coroners', 1),
#  ('autopsy', 1),
#  ('unidentified', 1),
#  ('woman', 102),
#  ('mysterious', 31),
#  ('injuries', 1),
#  ('terrifying', 7),
#  ('secret', 26),
#  ('head', 11),
#  ('lucrative', 3),
#  ('family', 105),
#  ('business', 23),
#  ('passes', 3),
#  ('away', 12),
#  ('leaves', 20),
#  ('clan', 7),
#  ('extreme', 5),
#  ('odds', 9),
#  ('future', 24),
#  ('uruguayan', 1),
#  ('president', 5),
#  ('josé', 2),
#  ('mujica', 1),
#  ('fellow', 7),
#  ('tupamaro', 1),
#  ('political', 21),
#  ('fight', 29),
#  ('survive', 8),
#  ('12', 2),
#  ('solitary', 1),
#  ('confinement', 1),
#  ('torture', 1),
#  ('follow', 9),
#  ('meteoric', 2),
#  ('rise', 9),
#  ('bergling', 1),
#  ('avicii', 1),
#  ('swedish', 3),
#  ('teenager', 9),
#  ('creative', 7),
#  ('behind', 26),
#  ('wake', 11),
#  ('1984', 1),
#  ('young', 166),
#  ('programmer', 1),
#  ('begins', 29),
#  ('question', 7),
#  ('reality', 9),
#  ('adapts', 1),
#  ('fantasy', 4),
#  ('novel', 6),
#  ('video', 8),
#  ('game', 25),
#  ('mind-bending', 3),
#  ('tale', 11),
#  ('multiple', 2),
#  ('endings', 1),
#  ('honest', 4),
#  ('though', 2),
#  ('overzealous', 1),
#  ('police', 27),
#  ('officer', 12),
#  ('strives', 5),
#  ('good', 14),
#  ('work', 21),
#  ('dealing', 2),
#  ('bickering', 5),
#  ('parents', 16),
#  ('incompetent', 1),
#  ('coworkers', 1),
#  ('vengeful', 4),
#  ('son', 39),
#  ('cop', 21),
#  ('mission', 22),
#  ('wannabe', 1),
#  ('actress', 3),
#  ('jilted', 2),
#  ('lover', 8),
#  ('intermingling', 1),
#  ('ways', 8),
#  ('24', 2),
#  ('hours', 2),
#  ('mumbai', 23),
#  ('humboldt', 1),
#  ('county', 2),
#  ('california', 5),
#  ('big', 17),
#  ('legal', 4),
#  ('marijuana', 2),
#  ('visitors', 1),
#  ('around', 23),
#  ('never', 7),
#  ('seen', 2),
#  ('details', 3),
#  ('rock', 10),
#  ('oasis', 2),
#  ('creativity', 1),
#  ('chaos', 7),
#  ('brothers', 16),
#  ('noel', 1),
#  ('liam', 1),
#  ('gallagher', 1),
#  ('brought', 4),
#  ('band', 15),
#  ('unemployment', 1),
#  ('drug', 25),
#  ('addiction', 5),
#  ('corruption', 15),
#  ('plague', 2),
#  ('drama', 25),
#  ('depicts', 2),
#  ('believe', 3),
#  ('still', 9),
#  ('two', 107),
#  ('cricket', 4),
#  ('prodigies', 1),
#  ('struggle', 10),
#  ('overbearing', 2),
#  ('father', 58),
#  ('system', 8),
#  ('stacked', 1),
#  ('realize', 4),
#  ('ambitions', 6),
#  ('identities', 4),
#  ('intimate', 12),
#  ('look', 20),
#  ('são', 1),
#  ('paulo', 1),
#  ('birth', 6),
#  ('center', 7),
#  ('features', 1),
#  ('interviews', 17),
#  ('mothers', 3),
#  ('activists', 2),
#  ('doctors', 4),
#  ('midwives', 1),
#  ('businessman', 14),
#  ('falls', 32),
#  ('asleep', 1),
#  ('wheel', 2),
#  ('car', 9),
#  ('interactions', 1),
#  ('scared', 2),
#  ('friend', 36),
#  ('unleash', 2),
#  ('string', 3),
#  ('lights', 3),
#  ('imbue', 1),
#  ('extraordinary', 9),
#  ('powers', 7),
#  ('goes', 21),
#  ('authorities', 2),
#  ('harbors', 3),
#  ('crush', 7),
#  ('millions', 6),
#  ('earth', 19),
#  ('suddenly', 9),
#  ('disappear', 1),
#  ('pilot', 4),
#  ('flying', 2),
#  ('plane', 3),
#  ('stuck', 6),
#  ('30,000', 1),
#  ('feet', 1),
#  ('must', 58),
#  ('way', 39),
#  ('ensure', 2),
#  ('passengers', 1),
#  ('survival', 10),
#  ('end', 10),
#  ('war', 38),
#  ('ii', 7),
#  ('french', 9),
#  ('doctor', 16),
#  ('red', 2),
#  ('cross', 5),
#  ('treats', 3),
#  ('nuns', 3),
#  ('polish', 3),
#  ('convent', 2),
#  ('raped', 3),
#  ('impregnated', 1),
#  ('russian', 4),
#  ('soldiers', 9),
#  ('obsessed', 1),
#  ('aspiring', 14),
#  ('writer', 15),
#  ('charming', 5),
#  ('bookstore', 1),
#  ('measures', 3),
#  ('insert', 1),
#  ('superheroes', 2),
#  ('amass', 1),
#  ('stop', 18),
#  ('intergalactic', 2),
#  ('sociopath', 1),
#  ('thanos', 1),
#  ('acquiring', 1),
#  ('infinity', 1),
#  ('stones', 1),
#  ('wiping', 1),
#  ('half', 4),
#  ('universe', 6),
#  ('haunted', 13),
#  ('visions', 2),
#  ('dead', 9),
#  ('psychologist', 2),
#  ('peter', 4),
#  ('returns', 27),
#  ('home', 45),
#  ('confront', 8),
#  ('long-ago', 1),
#  ('trauma', 2),
#  ('trip', 16),
#  ('exorcise', 1),
#  ('embolden', 1),
#  ('ghosts', 8),
#  ('chronic', 3),
#  ('gamer', 1),
#  ('abysmally', 1),
#  ('inept', 1),
#  ('academics', 2),
#  ('finally', 5),
#  ('meets', 26),
#  ('usual', 1),
#  ('shady', 3),
#  ('arcade', 1),
#  ('rich', 11),
#  ('classmate', 4),
#  ('akira', 1),
#  ('brian', 4),
#  ('regan', 1),
#  ('blends', 3),
#  ('trademark', 2),
#  ('observational', 1),
#  ('short', 12),
#  ('sketches', 9),
#  ('bit', 1),
#  ('audience', 6),
#  ('interaction', 1),
#  ('hybrid', 3),
#  ('u.s', 21),
#  ('taiwanese', 1),
#  ('immigrant', 4),
#  ('hometown', 7),
#  ('daughter', 34),
#  ('tow', 1),
#  ('assist', 2),
#  ('bed-and-breakfast', 1),
#  ('elementary', 1),
#  ('school', 59),
#  ('student', 29),
#  ('kenichi', 1),
#  ('mitsuba', 1),
#  ('household', 6),
#  ('gains', 3),
#  ('surprising', 4),
#  ('member', 5),
#  ('kanzo', 1),
#  ('hattori', 1),
#  ('mischievous', 2),
#  ('helpful', 2),
#  ('ninja', 1),
#  ('unruly', 3),
#  ('turn', 16),
#  ('unconventionally', 1),
#  ('opinionated', 1),
#  ('paths', 13),
#  ('tempting', 1),
#  ('gardener', 1),
#  ('warren', 1),
#  ('rabbits', 1),
#  ('battles', 5),
#  ('many', 3),
#  ('threats', 2),
#  ('daring', 7),
#  ('adaptation', 6),
#  ('classic', 10),
#  ('richard', 4),
#  ('adams', 1),
#  ('catch', 5),
#  ('criminal', 12),
#  ('masterminds', 1),
#  ('cops', 8),
#  ('teams', 12),
#  ('forensic', 1),
#  ('pathologist', 1),
#  ('see', 13),
#  ('murder', 36),
#  ('victim', 5),
#  ('moments', 3),
#  ('death', 34),
#  ('learning', 10),
#  ('ex-military', 1),
#  ('killed', 9),
#  ('highly', 2),
#  ('trained', 4),
#  ('john', 10),
#  ('gold', 3),
#  ('comes', 18),
#  ('town', 27),
#  ('seeking', 10),
#  ('answers', 12),
#  ('revenge', 19),
#  ('temporary', 1),
#  ('personal', 20),
#  ('chef', 8),
#  ('terminally', 2),
#  ('ill', 3),
#  ('single', 10),
#  ('mother', 36),
#  ('form', 13),
#  ('unlikely', 9),
#  ('bond', 17),
#  ('redefines', 1),
#  ('meaning', 7),
#  ('four', 39),
#  ('friends', 80),
#  ('spirited', 4),
#  ('navigate', 10),
#  ('treacherous', 2),
#  ('romance', 21),
#  ('even', 11),
#  ('stands', 6),
#  ('friendship', 18),
#  ('excitement', 3),
#  ('scenes', 9),
#  ('days', 12),
#  ('leading', 6),
#  ('major', 17),
#  ('live', 27),
#  ('worlds', 3),
#  ('fashion', 7),
#  ('space', 6),
#  ('food', 5),
#  ('troubled', 11),
#  ('past', 28),
#  ('scam', 4),
#  ('artist', 13),
#  ('runs', 14),
#  ('petty', 5),
#  ('racket', 2),
#  ('adoptive', 1),
#  ('mom', 8),
#  ('finds', 58),
#  ('redemption', 3),
#  ('mentoring', 2),
#  ('difficult', 4),
#  ('students', 18),
#  ('five', 20),
#  ('ominous', 2),
#  ('unseen', 3),
#  ('presence', 4),
#  ('drives', 5),
#  ('suicide', 9),
#  ('survivor', 3),
#  ('children', 14),
#  ('desperate', 10),
#  ('bid', 3),
#  ('reach', 4),
#  ('safety', 2),
#  ('girl', 49),
#  ('missing', 8),
#  ('priest', 5),
#  ('joins', 13),
#  ('demon', 10),
#  ('hunter', 1),
#  ('motley', 2),
#  ('crew', 17),
#  ('otherworldly', 3),
#  ('diagnosed', 5),
#  ('condition', 1),
#  ('could', 13),
#  ('infertile', 1),
#  ('choose', 6),
#  ('bachelors', 4),
#  ('baby', 7),
#  ('time', 17),
#  ('crossing', 1),
#  ('crime', 17),
#  ('scene', 6),
#  ('renowned', 3),
#  ('math', 4),
#  ('teacher', 15),
#  ('antiques', 2),
#  ('appraiser', 1),
#  ('embark', 8),
#  ('love', 92),
#  ('self-discovery', 2),
#  ('radically', 1),
#  ('changed', 9),
#  ('misunderstanding', 2),
#  ('13', 4),
#  ('biotech', 1),
#  ('expert', 9),
#  ('old', 28),
#  ('flame', 2),
#  ('suffers', 4),
#  ('illness', 4),
#  ('singer', 8),
#  ('found', 6),
#  ('murdered', 4),
#  ('scent', 1),
#  ('glands', 1),
#  ('excised', 1),
#  ('body', 14),
#  ('detectives', 4),
#  ('probe', 1),
#  ('attended', 1),
#  ('boarding', 2),
#  ('imperial', 2),
#  ('tokyo', 2),
#  ('calling', 2),
#  ('jaegers', 1),
#  ('secretly', 1),
#  ('hunt', 6),
#  ('vampires', 1),
#  ('ark', 1),
#  ('sirius', 1),
#  ('among', 4),
#  ('werewolf', 1),
#  ('yuliy', 1),
#  ('artists', 5),
#  ('la', 4),
#  ('discover', 19),
#  ('forgotten', 1),
#  ('sculptor', 1),
#  ('stanislav', 1),
#  ('szukalski', 1),
#  ('mad', 1),
#  ('genius', 3),
#  ('whose', 27),
#  ('true', 40),
#  ('chapter', 3),
#  ('astounding', 1),
#  ('biblical', 3),
#  ('hangover', 1),
#  ('spoof', 2),
#  ('apostles', 1),
#  ('awaken', 3),
#  ('jesus', 5),
#  ('piece', 2),
#  ('together', 21),
#  ('previous', 1),
#  ('last', 18),
#  ('supper', 1),
#  ('struggling', 18),
#  ('alone', 5),
#  ('post-apocalypse', 1),
#  ('offered', 2),
#  ('protection', 4),
#  ('unknown', 1),
#  ('man', 97),
#  ('village', 29),
#  ('may', 25),
#  ('imagines', 1),
#  ('tasked', 6),
#  ('risky', 3),
#  ('missions', 3),
#  ('turkey', 3),
#  ('members', 12),
#  ('special-operations', 1),
#  ('unit', 3),
#  ('danger', 6),
#  ('tragedy', 7),
#  ('field', 3),
#  ('working', 14),
#  ('artificial', 4),
#  ('intelligence', 8),
#  ('investigate', 5),
#  ('failure', 4),
#  ('mars', 2),
#  ('landing', 1),
#  ('controller', 1),
#  ('makes', 15),
#  ('astonishing', 2),
#  ('discovery', 1),
#  ('army', 11),
#  ('recruit', 2),
#  ('forced', 18),
#  ('haunting', 6),
#  ('jungle', 4),
#  ('island', 4),
#  ('training', 4),
#  ('camp', 5),
#  ('retsuko', 1),
#  ('desperately', 4),
#  ('plans', 10),
#  ('christmas', 11),
#  ('eve', 4),
#  ('obsession', 5),
#  ('validation', 1),
#  ('spirals', 2),
#  ('control', 8),
#  ('looking', 8),
#  ('moves', 17),
#  ('ikebukuro', 1),
#  ('district', 1),
#  ('mystery', 5),
#  ('present', 5),
#  ('mesh', 1),
#  ('brawl', 1),
#  ('lands', 5),
#  ('boys', 13),
#  ('seems', 3),
#  ('promising', 2),
#  ('path', 12),
#  ('loyalty', 2),
#  ('gangster', 13),
#  ('buddy', 3),
#  ('leads', 22),
#  ('bigger', 3),
#  ('trouble', 7),
#  ('seducing', 1),
#  ('philandering', 3),
#  ('con', 6),
#  ('rebellious', 3),
#  ('enlists', 5),
#  ('carrying', 1),
#  ('heinous', 1),
#  ('sister', 23),
#  ('radio', 4),
#  ('talk-show', 1),
#  ('turned', 7),
#  ('upside', 5),
#  ('murderous', 3),
#  ('caller', 2),
#  ('dials', 1),
#  ('program', 4),
#  ('asks', 3),
#  ('entangling', 1),
#  ('movie', 8),
#  ('chauffeur', 1),
#  ('prostitute', 4),
#  ('pimp', 1),
#  ('bold', 2),
#  ('reveals', 8),
#  ('ugly', 2),
#  ('truths', 9),
#  ('beneath', 4),
#  ('glitzy', 1),
#  ('veneer', 1),
#  ('first', 29),
#  ('since', 4),
#  ('2003', 1),
#  ('ellen', 1),
#  ('revisits', 3),
#  ('stardom', 7),
#  ('heartfelt', 2),
#  ('hilarious', 7),
#  ('lessons', 4),
#  ('learned', 2),
#  ('along', 14),
#  ('dystopian', 1),
#  ('near-future', 3),
#  ('united', 2),
#  ('states', 1),
#  ('deportation', 1),
#  ('caseworker', 1),
#  ('begun', 1),
#  ('authority', 1),
#  ('tries', 28),
#  ('safeguard', 2),
#  ('give', 6),
#  ('maternal', 1),
#  ('instincts', 3),
#  ('kicking', 1),
#  ('abducted', 3),
#  ('imprisoned', 6),
#  ('brutalized', 2),
#  ('vicious', 3),
#  ('gang', 16),
#  ('teddy', 1),
#  ('missed', 2),
#  ('festival', 2),
#  ('bowling', 1),
#  ('alley', 2),
#  ('snowed', 1),
#  ('worry', 2),
#  ('emil', 1),
#  ('insists', 3),
#  ('moose', 1),
#  ('save', 23),
#  ('day', 17),
#  ('jersey', 2),
#  ('detective', 20),
#  ('international', 2),
#  ('bangkok', 3),
#  ('quest', 15),
#  ('bring', 16),
#  ('empire', 5),
#  ('experts', 5),
#  ('sides', 5),
#  ('debate', 5),
#  ('questions', 7),
#  ('routine', 3),
#  ('practice', 3),
#  ('non-religious', 1),
#  ('infant', 3),
#  ('circumcision', 1),
#  ('visually', 2),
#  ('impaired', 2),
#  ('careens', 1),
#  ('shocking', 5),
#  ('twists', 1),
#  ('unintentionally', 1),
#  ('hidden', 6),
#  ('floral', 1),
#  ('goddess', 2),
#  ('naïve', 4),
#  ('jinmi', 1),
#  ('drawn', 3),
#  ('xufeng', 1),
#  ('heavenly', 1),
#  ('emperor', 4),
#  ('yet', 5),
#  ('forces', 12),
#  ('conspire', 2),
#  ('train', 11),
#  ('dragon', 4),
#  ('adventure', 16),
#  ('continues', 4),
#  ('lost', 8),
#  ('sheep', 1),
#  ('turns', 15),
#  ('fierce', 4),
#  ('fun-filled', 1),
#  ('competition', 10),
#  ('join', 11),
#  ('dreamworks', 1),
#  ('holiday', 5),
#  ('specials', 4),
#  ('featuring', 11),
#  ('shrek', 2),
#  ('donkey', 3),
#  ('hiccup', 1),
#  ('toothless', 1),
#  ('wacky', 2),
#  ('animals', 6),
#  ('madagascar', 1),
#  ('1980s', 8),
#  ('crusading', 1),
#  ('journalist', 12),
#  ('uncovers', 6),
#  ('cia', 3),
#  ('funding', 1),
#  ('nicaraguan', 1),
#  ('rebels', 3),
#  ('silence', 5),
#  ('investigation', 7),
#  ('showbiz', 5),
#  ('revolving', 1),
#  ...]

# %%
## Creating a list of the polarity of the descriptions of various content added in 2019
b=[]
for i in blob_2.sentences:
    b.append(i.polarity)
print(b)
# Out:
# [0.1, 0.05, 0.0, 0.175, 0.11904761904761905, 0.3, 0.35714285714285715, 0.5, 0.07222222222222223, 0.125, 0.044444444444444446, 0.0, 0.35714285714285715, 0.225, 0.4, -0.15, 0.0625, 0.8, 0.25, 0.15, 0.04999999999999999, 0.0, 0.5499999999999999, 0.2833333333333333, 0.0, -0.15496031746031746, 0.1875, 0.03333333333333333, 0.36818181818181817, 0.0, -0.4666666666666666, -0.125, 0.0, -0.00833333333333334, -0.15, 0.0, 0.3166666666666666, 0.1, 0.1, 0.0, 0.25, 0.7, 0.3, 0.05, 0.0, -0.15, 0.16666666666666666, 0.0, 0.0, 0.024999999999999984, 0.09166666666666666, -0.2, 0.0, -0.03125, 0.0, 0.1, 0.3090909090909091, 0.06818181818181818, 0.2676767676767677, -0.15833333333333335, -0.020000000000000004, -0.19428571428571428, 0.75, -0.06704545454545456, -0.4166666666666667, -0.04999999999999999, -0.019999999999999997, 0.0, 0.3, -0.1875, 0.0, -0.4, 0.1, 0.10833333333333332, -0.07333333333333333, 0.0, 0.0, -0.15416666666666667, -0.475, -0.14343434343434344, -0.049999999999999996, 0.0, 0.1, -0.07685185185185187, -0.18333333333333332, 0.2767857142857143, 0.0, -1.0, 0.0, 0.0, -0.12383838383838386, -0.3333333333333333, -0.16666666666666666, 0.0, 0.0, 0.5, -0.4, 0.06666666666666667, 0.16666666666666666, 0.1, 0.0, -0.7999999999999999, 0.0, -0.013333333333333308, -0.3944444444444445, 0.09375, -0.5, -0.35, 0.0, 0.06818181818181818, 0.3621212121212121, 0.0, -0.23333333333333328, 0.31666666666666665, 0.25, 0.0, -0.2, 0.2772727272727272, -0.15, 0.03166666666666666, 0.475, 0.0, 0.0, 0.125, 0.0, 0.0, -0.10000000000000002, 0.0, 0.1, 0.4285714285714286, -0.525, -0.1, -0.10000000000000002, -0.049999999999999996, -0.8, -0.3, 0.5, -0.4, 0.2, 0.38, 0.0, 0.5, 0.16666666666666666, 0.009090909090909094, 0.0, -0.0625, 0.4000000000000001, 0.0, 0.4875, 0.03333333333333333, 0.0, -0.12121212121212122, 0.0, 0.05, 0.18227272727272728, -0.03333333333333335, 0.0, 0.2, 0.0, -0.06666666666666667, 0.45, -0.375, -0.03333333333333335, 0.0, -0.18571428571428572, 0.5, -0.6, 0.25625, 0.0, 0.37499999999999994, 0.13636363636363635, 0.0, -0.2125, 0.3333333333333333, 0.19999999999999998, -0.125, -0.04999999999999999, -0.10000000000000002, 0.25, 0.5, 0.018181818181818174, 0.0, -0.4, 0.15, 0.0, -0.071875, -0.12916666666666668, -0.10000000000000002, 0.4375, 0.3523809523809524, 0.075, -0.125, 0.1875, -0.2, -0.2, -0.5, -0.16111111111111112, -0.008333333333333325, -0.15, 0.4, 0.0, 0.21666666666666667, 0.0, 0.0, 0.25, 0.1875, 0.35416666666666663, 0.3, -0.16666666666666666, -0.04999999999999999, -0.09666666666666664, 0.1277777777777778, 0.1, 0.0, -0.5, -0.3277777777777778, 0.5, 0.2285714285714286, 0.0, 0.4375, 0.35714285714285715, 0.0, 0.0, 1.0, 0.3333333333333333, 0.0, 0.05555555555555555, 0.25, -0.08181818181818182, 0.0, -0.05, 0.13636363636363635, -0.2, -0.25, 0.0, 0.5, 0.17857142857142858, -0.2, 0.37142857142857144, 0.07500000000000001, 0.0625, -0.0666666666666667, 0.1, 0.016666666666666666, 0.12159090909090908, -0.19999999999999998, -0.10416666666666667, 0.0, -0.13181818181818183, 0.35, 0.25, 0.125, 0.11481481481481481, 0.11333333333333333, 0.0, -0.19, 0.0, 0.6, 0.3, -0.053409090909090906, -0.16, 0.24545454545454545, 0.35, 0.15, 0.14999999999999997, 0.0, -0.2589285714285714, 0.25, 0.1, 0.0, -0.03333333333333333, 0.04545454545454545, -0.024999999999999994, 0.5, 0.35, 0.0, 0.5, -0.29999999999999993, -0.02022727272727274, 0.425, 0.26666666666666666, -0.11666666666666665, -1.850371707708594e-17, 0.0, 0.0, 0.13636363636363635, -0.1, -0.5, 0.04924242424242423, 0.04616161616161616, -0.0625, 0.03333333333333333, -0.1, 0.1, 0.0, 0.0375, 0.3, 0.3444444444444444, 0.0, 0.39999999999999997, 0.0, 0.3090909090909091, -0.0625, -0.015000000000000003, 0.0, 0.5, 0.1, 0.13333333333333333, 0.0, 0.3666666666666667, 0.0, 0.4375, 0.5803571428571429, 0.0, -0.2518518518518518, 0.14250000000000002, 0.0006060606060605877, 0.0, 0.0, 0.0, -0.051851851851851864, 0.0, 0.0, 0.2, 0.25, 0.1, -0.1875, 0.0, 0.04, 0.05555555555555555, -0.1, 0.2, -0.3416666666666667, -0.15000000000000002, 0.1, 0.2, 0.3333333333333333, -0.15, 0.056666 ...

# %%
### Sentiment of content added in 2018 based on index
plt.plot(df_18.index[:20],b[:20], color='purple',marker='*',linewidth=1)
# add a title
plt.title("Sentiment for various content added in 2018 based on index")
# add a label to the y-axis
plt.ylabel("Sentiment")
plt.xlabel("Index")
plt.show()

# %%
# Top 20 common words found in the description for 2018 content
sorted_items_2 = sorted(items, key=itemgetter(1), reverse=True)
top20 = sorted_items_2[0:20]
top20
# Out:
# [('young', 166),
#  ('life', 136),
#  ('new', 113),
#  ('two', 107),
#  ('family', 105),
#  ('woman', 102),
#  ('world', 98),
#  ('man', 97),
#  ('love', 92),
#  ('friends', 80),
#  ('one', 70),
#  ('find', 65),
#  ('documentary', 64),
#  ('school', 59),
#  ('three', 58),
#  ('father', 58),
#  ('must', 58),
#  ('finds', 58),
#  ('takes', 53),
#  ('series', 53)]

# %%
### bargraph showing the top 20 words found in description for 2018
d2= pd.DataFrame(top20, columns=['word', 'count'])
axes = d.plot.bar(x='word', y='count', legend=False,color = 'blue')
plt.xlabel('Most Common Words')
plt.ylabel('Frequency')
plt.title('Most Common Words from content added in 2018')
plt.gcf().tight_layout()
